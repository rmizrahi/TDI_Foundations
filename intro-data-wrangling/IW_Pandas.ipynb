# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 144

# %%
import re
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#RBM: next added after stats notebook review:
import scipy as sp
from scipy.stats import norm
#RBM: end additions
from pandas import DataFrame

# %% [markdown]
# # Pandas
# <!-- requirement: images/Data_Frame_Data_Series.png -->
# <!-- requirement: small_data/fha_by_tract.csv -->
# <!-- requirement: small_data/2013_Gaz_tracts_national.tsv -->

# %% [markdown]
# Pandas is Python's answer to R.  It's a good tool for small(ish) data analysis -- i.e. when everything fits into memory.
#
# The basic new "noun" in pandas is the **DataFrame**.

# %% [markdown]
# ## Nouns (objects) in Pandas
#
# ### Data Frames
#
# Like a table, with rows and columns (e.g. as in SQL).  Except:
#   - The rows can be indexed by something interesting (there is special support for labels like categorical and timeseries data).  This is especially useful when you have timeseries data with potentially missing data points.
#   - Cells can store Python objects. Like in SQL, columns are type homogeneous.
#   - Instead of "NULL", the name for a non-existent value is "NA".  Unlike R, Python's data frames only support NAs in columns of some data types (basically: floating point numbers and 'objects') -- but this is mostly a non-issue (because it will "up-cast" integers to float64, etc.)
#
# ### Data Series:
# These are named columns of a DataFrame (more correctly, a DataFrame is a dictionary of Series).  The entries of the series have homogeneous type.
#
# ![Data Frame Data Series](images/Data_Frame_Data_Series.png)
# [comment]: https://docs.google.com/drawings/d/1eQOWaG37cH6Uo13zfRVPWsA77F0U4WVG2y06Z3NOtAU/edit

# %%
# a data frame
df1 = pd.DataFrame({
    'number': [1, 2, 3],
    'animal': ['cat', 'dog', 'mouse']
})

df1
# Out:
#   animal  number
# 0    cat       1
# 1    dog       2
# 2  mouse       3

# %%
#RBM Practice
df3 = pd.DataFrame({
    'color': ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet'],
    'number': [1,2,3,4,5,6,7]
})

df3
# Out:
#     color  number
# 0     red       1
# 1  orange       2
# 2  yellow       3
# 3   green       4
# 4    blue       5
# 5  indigo       6
# 6  violet       7

# %%
df1['animal']  # a series
# Out:
# 0      cat
# 1      dog
# 2    mouse
# Name: animal, dtype: object

# %%
#RBM Practice
df3['color']
# Out:
# 0       red
# 1    orange
# 2    yellow
# 3     green
# 4      blue
# 5    indigo
# 6    violet
# Name: color, dtype: object

# %%
# the same data frame
df2 = pd.DataFrame([
    ('cat', 1),
    ('dog', 2),
    ('mouse', 3),
], columns=['animal', 'number'])

np.all(df1 == df2)
# Out:
# True

# %%
# RBM Practice
df4 = pd.DataFrame([
    ('red',1),
    ('orange',2),
    ('yellow',3),
    ('green',4),
    ('blue',5),
    ('indigo',6),
    ('violet',7),
], columns=['color','number'])

np.all(df3==df4)
# Out:
# True

# %%
pd.DataFrame(columns=['animal','number'])
# Out:
# Empty DataFrame
# Columns: [animal, number]
# Index: []

# %%
# RBM Practice
pd.DataFrame(columns=['color','number'])
# Out:
# Empty DataFrame
# Columns: [color, number]
# Index: []

# %% [markdown]
# ## Verbs (operations) in Pandas
#
# Pandas provides a "batteries-included" basic data analysis:
#   - **Loading data:** `read_csv`, `read_table`, `read_sql`, and `read_html`
#   - **Selection, filtering, and aggregation** (i.e. SQL-type operations): There's a special syntax for `SELECT`ing.  There's the `merge` method for `JOIN`ing.  There's also an easy syntax for what in SQL is a mouthful: Creating a new column whose value is computed from another column -- with the bonus that now the computations can use the full power of Python (though it might be faster if it didn't).
#   - **"Pivot table" style aggregation:** If you're an Excel cognoscenti, you may appreciate this.
#   - **NA handling:** Like R's data frames, there is good support for transforming NA values with default values / averaging tricks / etc.
#   - **Basic statistics:** e.g. `mean`, `median`, `max`, `min`, and the convenient `describe`.
#   - **Plugging into more advanced analytics:** Okay, this isn't batteries included.  But still, it plays reasonably with `sklearn`.
#   - **Visualization:** For instance `plot` and `hist`.
#
# We'll go through a little on all of these in the context of an example.  To go through it, you must have the (output) data files from the HMDA "Project structure" example.  We're going to explore a dataset of mortgage insurance issued by the Federal Housing Authority (FHA).  The data is broken down by census tract and tells us how big of a player the FHA is in each tract (how many homes etc.).

# %% [markdown]
# ## Loading data (and basic statistics / visualization)

# %%
names =["State_Code", "County_Code", "Census_Tract_Number", "NUM_ALL",
        "NUM_FHA", "PCT_NUM_FHA", "AMT_ALL", "AMT_FHA", "PCT_AMT_FHA"]
# Loading a CSV file, without a header (so we have to provide field names)
df = pd.read_csv('small_data/fha_by_tract.csv', names=names)
df.head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA
# 0        100.0      258      258        100.0
# 1        100.0       71       71        100.0
# 2        100.0      215      215        100.0
# 3        100.0      206      206        100.0
# 4        100.0      303      303        100.0

# %%
df['GEOID'] = (df['Census_Tract_Number']*100 + 10**6 * df['County_Code']
               + 10**9 * df['State_Code'])   # A computed field!
df.head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID
# 0        100.0      258      258        100.0           NaN
# 1        100.0       71       71        100.0  2.804901e+10
# 2        100.0      215      215        100.0           NaN
# 3        100.0      206      206        100.0  3.911306e+10
# 4        100.0      303      303        100.0  1.210501e+10

# %%
df.describe()
# Out:
#          State_Code   County_Code  Census_Tract_Number       NUM_ALL  \
# count  72034.000000  71984.000000         71040.000000  72035.000000
# mean      28.322528     85.612636          2534.598023     36.970389
# std       16.459507     98.672445          3451.173223     53.975403
# min        1.000000      1.000000             1.000000      1.000000
# 25%       13.000000     29.000000           103.020000     13.000000
# 50%       28.000000     63.000000           442.010000     27.000000
# 75%       42.000000    109.000000          4503.012500     48.000000
# max       72.000000    840.000000          9922.010000   9477.000000
#
#             NUM_FHA   PCT_NUM_FHA       AMT_ALL        AMT_FHA   PCT_AMT_FHA  \
# count  72035.000000  72035.000000  7.203500e+04   72035.000000  72035.000000
# mean       9.741667     28.566878  7.886092e+03    1689.278851     29.703179
# std       15.187832     22.404545  1.302542e+04    2800.346300     24.037779
# min        0.000000      0.000000  2.000000e+00       0.000000      0.000000
# 25%        2.000000     11.111100  1.551000e+03     281.000000     10.780800
# 50%        6.000000     25.000000  4.168000e+03     932.000000     24.753900
# 75%       13.000000     41.935500  9.668000e+03    2197.000000     44.207550
# max     1932.000000    100.000000  1.575871e+06  331515.000000    100.000000
#
#               GEOID
# count  7.104000e+04
# mean   2.837319e+10
# std    1.648784e+10
# min    1.001020e+09
# 25%    1.301596e+10
# 50%    2.804900e+10
# 75%    4.200348e+10
# max    7.215375e+10

# %%
df.dtypes
# Out:
# State_Code             float64
# County_Code            float64
# Census_Tract_Number    float64
# NUM_ALL                  int64
# NUM_FHA                  int64
# PCT_NUM_FHA            float64
# AMT_ALL                  int64
# AMT_FHA                  int64
# PCT_AMT_FHA            float64
# GEOID                  float64
# LOG_AMT_ALL            float64
# dtype: object

# %%
df['Census_Tract_Number'] * 100
# Out:
# 0             NaN
# 1         10301.0
# 2             NaN
# 3         60300.0
# 4         12404.0
# 5        980800.0
# 6        120200.0
# 7         20700.0
# 8          3000.0
# 9             NaN
# 10         8704.0
# 11         1801.0
# 12         6400.0
# 13          703.0
# 14        13802.0
# 15       252201.0
# 16            NaN
# 17       805602.0
# 18       101501.0
# 19       959700.0
# 20         8101.0
# 21        11300.0
# 22       181300.0
# 23        27602.0
# 24       152603.0
# 25       505400.0
# 26          301.0
# 27        40525.0
# 28         8110.0
# 29       430500.0
#            ...
# 72005      4900.0
# 72006      8613.0
# 72007    931700.0
# 72008         NaN
# 72009    433801.0
# 72010    976700.0
# 72011     12600.0
# 72012     24301.0
# 72013     30500.0
# 72014    381602.0
# 72015      7906.0
# 72016      3707.0
# 72017    204400.0
# 72018    801300.0
# 72019    200100.0
# 72020    205801.0
# 72021     19000.0
# 72022    970100.0
# 72023    190301.0
# 72024     21409.0
# 72025    967800.0
# 72026    505200.0
# 72027       601.0
# 72028      2300.0
# 72029       500.0
# 72030         NaN
# 72031         NaN
# 72032     55800.0
# 72033       800.0
# 72034    273902.0
# Name: Census_Tract_Number, Length: 72035, dtype: float64

# %%
df.drop?

# %% [markdown]
# To drop a column:

# %%
df.drop('GEOID', axis=1).head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA  LOG_AMT_ALL
# 0        100.0      258      258        100.0     5.556828
# 1        100.0       71       71        100.0     4.276666
# 2        100.0      215      215        100.0     5.375278
# 3        100.0      206      206        100.0     5.332719
# 4        100.0      303      303        100.0     5.717028

# %%
df
# Out:
#        State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0             8.0         75.0                  NaN        1        1
# 1            28.0         49.0               103.01        1        1
# 2            40.0          3.0                  NaN        1        1
# 3            39.0        113.0               603.00        3        3
# 4            12.0        105.0               124.04        2        2
# 5            12.0         86.0              9808.00        1        1
# 6            39.0         35.0              1202.00        1        1
# 7            12.0        103.0               207.00        2        2
# 8            36.0        119.0                30.00        1        1
# 9            39.0        153.0                  NaN        1        1
# 10           48.0        113.0                87.04        1        1
# 11           12.0         86.0                18.01        1        1
# 12           13.0        121.0                64.00        1        1
# 13           12.0         81.0                 7.03        2        2
# 14           48.0         61.0               138.02        1        1
# 15           17.0         31.0              2522.01        2        2
# 16           34.0         31.0                  NaN        1        1
# 17           24.0         33.0              8056.02        2        2
# 18           39.0         35.0              1015.01        2        2
# 19           72.0         83.0              9597.00        1        1
# 20           13.0        121.0                81.01        1        1
# 21           34.0         13.0               113.00        2        2
# 22           34.0         31.0              1813.00        7        7
# 23           22.0         51.0               276.02        2        2
# 24           39.0         35.0              1526.03        2        2
# 25           39.0        153.0              5054.00        5        5
# 26            4.0         27.0                 3.01        2        2
# 27           13.0         63.0               405.25        1        1
# 28           47.0        157.0                81.10        1        1
# 29           17.0         31.0              4305.00        2        2
# ...           ...          ...                  ...      ...      ...
# 72005        37.0        119.0                49.00        1        0
# 72006        15.0          3.0                86.13        3        0
# 72007        21.0        195.0              9317.00        4        0
# 72008        27.0        109.0                  NaN        1        0
# 72009         6.0         37.0              4338.01       10        0
# 72010        46.0         69.0              9767.00        4        0
# 72011        36.0         61.0               126.00      134        0
# 72012        36.0         61.0               243.01        3        0
# 72013        19.0        125.0               305.00        5        0
# 72014        12.0        111.0              3816.02        1        0
# 72015        34.0         23.0                79.06        3        0
# 72016        12.0         86.0                37.07       63        0
# 72017        42.0         91.0              2044.00       31        0
# 72018        17.0         31.0              8013.00       52        0
# 72019        42.0         79.0              2001.00        3        0
# 72020        42.0         91.0              2058.01       10        0
# 72021        36.0         47.0               190.00        7        0
# 72022        51.0         91.0              9701.00        9        0
# 72023         6.0         37.0              1903.01        3        0
# 72024        13.0         89.0               214.09        3        0
# 72025        31.0        133.0              9678.00        8        0
# 72026        39.0        153.0              5052.00        1        0
# 72027        25.0         25.0                 6.01       26        0
# 72028         1.0        101.0                23.00        1        0
# 72029        31.0        109.0                 5.00       13        0
# 72030        48.0        221.0                  NaN        1        0
# 72031        30.0          NaN                  NaN        2        0
# 72032        36.0         47.0               558.00       10        0
# 72033        30.0         31.0                 8.00       21        0
# 72034         6.0         37.0              2739.02       43        0
#
#        PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID  LOG_AMT_ALL
# 0            100.0      258      258        100.0           NaN     5.556828
# 1            100.0       71       71        100.0  2.804901e+10     4.276666
# 2            100.0      215      215        100.0           NaN     5.375278
# 3            100.0      206      206        100.0  3.911306e+10     5.332719
# 4            100.0      303      303        100.0  1.210501e+10     5.717028
# 5            100.0      188      188        100.0  1.208698e+10     5.241747
# 6            100.0       19       19        100.0  3.903512e+10     2.995732
# 7            100.0      100      100        100.0  1.210302e+10     4.615121
# 8            100.0      354      354        100.0  3.611900e+10     5.872118
# 9            100.0      213      213        100.0           NaN     5.365976
# 10           100.0       64       64        100.0  4.811301e+10     4.174387
# 11           100.0       45       45        100.0  1.208600e+10     3.828641
# 12           100.0       61       61        100.0  1.312101e+10     4.127134
# 13           100.0      241      241        100.0  1.208100e+10     5.488938
# 14           100.0       66       66        100.0  4.806101e+10     4.204693
# 15           100.0      202      202        100.0  1.703125e+10     5.313206
# 16           100.0      164      164        100.0           NaN     5.105945
# 17           100.0      315      315        100.0  2.403381e+10     5.755742
# 18           100.0      145      145        100.0  3.903510e+10     4.983607
# 19           100.0       85       85        100.0  7.208396e+10     4.454347
# 20           100.0       68       68        100.0  1.312101e+10     4.234107
# 21           100.0      310      310        100.0  3.401301e+10     5.739793
# 22           100.0     1357     1357        100.0  3.403118e+10     7.213768
# 23           100.0      158      158        100.0  2.205103e+10     5.068904
# 24           100.0       92       92        100.0  3.903515e+10     4.532599
# 25           100.0      252      252        100.0  3.915351e+10     5.533389
# 26           100.0      156      156        100.0  4.027000e+09     5.056246
# 27           100.0       41       41        100.0  1.306304e+10     3.737670
# 28           100.0       40       40        100.0  4.715701e+10     3.713572
# 29           100.0      291      291        100.0  1.703143e+10     5.676754
# ...            ...      ...      ...          ...           ...          ...
# 72005          0.0       79        0          0.0  3.711900e+10     4.382027
# 72006          0.0     1094        0          0.0  1.500301e+10     6.998510
# 72007          0.0      242        0          0.0  2.119593e+10     5.493061
# 72008          0.0      150        0          0.0           NaN     5.017280
# 72009          0.0     2088        0          0.0  6.037434e+09     7.644441
# 72010          0.0      310        0          0.0  4.606998e+10     5.739793
# 72011          0.0    75510        0          0.0  3.606101e+10    11.232034
# 72012          0.0     2078        0          0.0  3.606102e+10     7.639642
# 72013          0.0      470        0          0.0  1.912503e+10     6.154858
# 72014          0.0       32        0          0.0  1.211138e+10     3.496508
# 72015          0.0      746        0          0.0  3.402301e+10     6.616065
# 72016          0.0    13673        0          0.0  1.208600e+10     9.523251
# 72017          0.0    11062        0          0.0  4.209120e+10     9.311361
# 72018          0.0    31968        0          0.0  1.703180e+10    10.372522
# 72019          0.0      432        0          0.0  4.207920e+10     6.070738
# 72020          0.0     1337        0          0.0  4.209121e+10     7.198931
# 72021          0.0     2780        0          0.0  3.604702e+10     7.930566
# 72022          0.0      932        0          0.0  5.109197e+10     6.838405
# 72023          0.0      457        0          0.0  6.037190e+09     6.126869
# 72024          0.0      432        0          0.0  1.308902e+10     6.070738
# 72025          0.0      283        0          0.0  3.113397e+10     5.648974
# 72026          0.0       30        0          0.0  3.915351e+10     3.433987
# 72027          0.0     7894        0          0.0  2.502500e+10     8.973985
# 72028          0.0       70        0          0.0  1.101002e+09     4.262680
# 72029          0.0      756        0          0.0  3.110900e+10     6.629363
# 72030          0.0      140        0          0.0           NaN     4.948760
# 72031          0.0      690        0          0.0           NaN     6.538140
# 72032          0.0     3273        0          0.0  3.604706e+10     8.093768
# 72033          0.0     5743        0          0.0  3.003100e+10     8.655911
# 72034          0.0    41953        0          0.0  6.037274e+09    10.644329
#
# [72035 rows x 11 columns]

# %% [markdown]
# Most operations produce copies (unless `inplace=True` is specified).  The `df` object still has the GEOID column.

# %%
'GEOID' in df.columns
# Out:
# True

# %% [markdown]
# Rows can also be dropped.  Note that the indices do not reset.  The index is associated with the row, not with the order.

# %%
df.drop(0, axis=0).head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
# 5        12.0         86.0              9808.00        1        1
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID
# 1        100.0       71       71        100.0  2.804901e+10
# 2        100.0      215      215        100.0           NaN
# 3        100.0      206      206        100.0  3.911306e+10
# 4        100.0      303      303        100.0  1.210501e+10
# 5        100.0      188      188        100.0  1.208698e+10

# %% [markdown]
# By default, rows are indexed by their position.  However, any column can be made into an index:

# %%
df.set_index('State_Code').head(6)
# Out:
#             County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  PCT_NUM_FHA  \
# State_Code
# 8.0                75.0                  NaN        1        1        100.0
# 28.0               49.0               103.01        1        1        100.0
# 40.0                3.0                  NaN        1        1        100.0
# 39.0              113.0               603.00        3        3        100.0
# 12.0              105.0               124.04        2        2        100.0
# 12.0               86.0              9808.00        1        1        100.0
#
#             AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID
# State_Code
# 8.0             258      258        100.0           NaN
# 28.0             71       71        100.0  2.804901e+10
# 40.0            215      215        100.0           NaN
# 39.0            206      206        100.0  3.911306e+10
# 12.0            303      303        100.0  1.210501e+10
# 12.0            188      188        100.0  1.208698e+10

# %% [markdown]
# Multiple levels of indexing is possible:

# %%
df.set_index(['State_Code', 'County_Code']).head(8)
# Out:
#                         Census_Tract_Number  NUM_ALL  NUM_FHA  PCT_NUM_FHA  \
# State_Code County_Code
# 8.0        75.0                         NaN        1        1        100.0
# 28.0       49.0                      103.01        1        1        100.0
# 40.0       3.0                          NaN        1        1        100.0
# 39.0       113.0                     603.00        3        3        100.0
# 12.0       105.0                     124.04        2        2        100.0
#            86.0                     9808.00        1        1        100.0
# 39.0       35.0                     1202.00        1        1        100.0
# 12.0       103.0                     207.00        2        2        100.0
#
#                         AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID
# State_Code County_Code
# 8.0        75.0             258      258        100.0           NaN
# 28.0       49.0              71       71        100.0  2.804901e+10
# 40.0       3.0              215      215        100.0           NaN
# 39.0       113.0            206      206        100.0  3.911306e+10
# 12.0       105.0            303      303        100.0  1.210501e+10
#            86.0             188      188        100.0  1.208698e+10
# 39.0       35.0              19       19        100.0  3.903512e+10
# 12.0       103.0            100      100        100.0  1.210302e+10

# %% [markdown]
# An index can be turned back into a column:

# %%
df.set_index('State_Code').reset_index().head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID
# 0        100.0      258      258        100.0           NaN
# 1        100.0       71       71        100.0  2.804901e+10
# 2        100.0      215      215        100.0           NaN
# 3        100.0      206      206        100.0  3.911306e+10
# 4        100.0      303      303        100.0  1.210501e+10

# %%
print "Percentage of mortages in each census tract insured by FHA"
df['PCT_AMT_FHA'].describe()
# Out:
# Percentage of mortages in each census tract insured by FHA
# count    72035.000000
# mean        29.703179
# std         24.037779
# min          0.000000
# 25%         10.780800
# 50%         24.753900
# 75%         44.207550
# max        100.000000
# Name: PCT_AMT_FHA, dtype: float64

# %% [markdown]
# We can also make a histogram of a column to explore the data further.

# %%
#df['PCT_AMT_FHA'].hist(bins=50, alpha=0.5)

# %%
sp.stats.norm?

# %%
# RBM Testing:

fig, ax = plt.subplots(1, 1)
mean, var, skew, kurt = norm.stats(moments='mvsk')
x = np.linspace(norm.ppf(0.01),norm.ppf(0.99), 100)
ax.plot(x, norm.pdf(x),'r-', lw=5, alpha=0.6, label='norm pdf')
rv = norm()
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')
vals = norm.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], norm.cdf(vals))
r = norm.rvs(size=1000)
ax.hist(r, normed=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %%
df['AMT_ALL'].hist(bins=50, alpha=0.5)

# %% [markdown]
# The above distribution looks skewed, so let's look at its logarithm.

# %%
df['LOG_AMT_ALL'] = np.log1p(df['AMT_ALL'])  # Create a new column to examine
print df['LOG_AMT_ALL'].describe()

df['LOG_AMT_ALL'].hist(bins=50)
# Out:
# count    72035.000000
# mean         8.170124
# std          1.429644
# min          1.098612
# 25%          7.347300
# 50%          8.335431
# 75%          9.176680
# max         14.270319
# Name: LOG_AMT_ALL, dtype: float64

# %% [markdown]
# ## Indexing data frames
#
# Indexing by a column name yields a data series.

# %%
df['State_Code'].head()
# Out:
# 0     8.0
# 1    28.0
# 2    40.0
# 3    39.0
# 4    12.0
# Name: State_Code, dtype: float64

# %% [markdown]
# Indexing by a list of column names gives another data frame.

# %%
df[['State_Code', 'County_Code']].head()
# Out:
#    State_Code  County_Code
# 0         8.0         75.0
# 1        28.0         49.0
# 2        40.0          3.0
# 3        39.0        113.0
# 4        12.0        105.0

# %% [markdown]
# **Question:** What will this return?

# %%
type(df[['State_Code']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# A data frame is an iterator that yields the column names:

# %%
[col for col in df]
# Out:
# ['State_Code',
#  'County_Code',
#  'Census_Tract_Number',
#  'NUM_ALL',
#  'NUM_FHA',
#  'PCT_NUM_FHA',
#  'AMT_ALL',
#  'AMT_FHA',
#  'PCT_AMT_FHA',
#  'GEOID',
#  'LOG_AMT_ALL']

# %% [markdown]
# To index a particular element of the frame, use the `.loc` attribute.  It takes index and column names.

# %%
df.loc[3, 'State_Code']
# Out:
# 39.0

# %% [markdown]
# Both can be sliced.  Unusually for Python, both endpoints are included in the slice.

# %%
df.loc[0:3, 'State_Code':'Census_Tract_Number']
# Out:
#    State_Code  County_Code  Census_Tract_Number
# 0         8.0         75.0                  NaN
# 1        28.0         49.0               103.01
# 2        40.0          3.0                  NaN
# 3        39.0        113.0               603.00

# %% [markdown]
# Position-based indexing is available in the `.iloc` attribute.

# %%
df.iloc[3, 0]
# Out:
# 39.0

# %%
df.iloc?

# %% [markdown]
# The usual slicing convention is used for `.iloc`.

# %%
df.iloc[0:3, 0:3]
# Out:
#    State_Code  County_Code  Census_Tract_Number
# 0         8.0         75.0                  NaN
# 1        28.0         49.0               103.01
# 2        40.0          3.0                  NaN

# %% [markdown]
# ## Indices in Pandas
#
# Pandas indices allow us to handle data naturally.  Elements are associated based on their index, not their order.

# %%
s1 = pd.Series([1,2,3], index=['a', 'b', 'c'])
s2 = pd.Series([3,2,1], index=['c', 'b', 'a'])
s1 + s2
# Out:
# a    2
# b    4
# c    6
# dtype: int64

# %%
s3 = pd.Series([3,2,1], index=['c', 'd', 'e'])
s1 + s3
# Out:
# a    NaN
# b    NaN
# c    6.0
# d    NaN
# e    NaN
# dtype: float64

# %% [markdown]
# Missing values get a NaN, but this can be replaced by a fill value of your choice.

# %%
s1.add(s3, fill_value=0)
# Out:
# a    1.0
# b    2.0
# c    6.0
# d    2.0
# e    1.0
# dtype: float64

# %% [markdown]
# ## Function application and mapping
#
# For element-wise function application, the most straightforward thing to do is to apply numpy functions to these objects:

# %%
df1 = pd.DataFrame(np.arange(24).reshape(4,6))
np.sin(df1)
# Out:
#           0         1         2         3         4         5
# 0  0.000000  0.841471  0.909297  0.141120 -0.756802 -0.958924
# 1 -0.279415  0.656987  0.989358  0.412118 -0.544021 -0.999990
# 2 -0.536573  0.420167  0.990607  0.650288 -0.287903 -0.961397
# 3 -0.750987  0.149877  0.912945  0.836656 -0.008851 -0.846220

# %% [markdown]
# This relies on numpy functions automatically broadcasting themselves to work element-wise.  To apply a pure-python function to each element, use the `.applymap()` method.

# %%
df1.applymap(lambda x: "%.2f" % x)
# Out:
#        0      1      2      3      4      5
# 0   0.00   1.00   2.00   3.00   4.00   5.00
# 1   6.00   7.00   8.00   9.00  10.00  11.00
# 2  12.00  13.00  14.00  15.00  16.00  17.00
# 3  18.00  19.00  20.00  21.00  22.00  23.00

# %% [markdown]
# However, sometimes you want to compute things column-wise or row-wise.  In this case, you will need to use the `apply` method.  For example, the following takes the range of each column.

# %%
df1.apply(lambda x: x.max() - x.min())
# Out:
# 0    18
# 1    18
# 2    18
# 3    18
# 4    18
# 5    18
# dtype: int64

# %% [markdown]
# And this takes the range of reach row.

# %%
df1.apply(lambda x: x.max() - x.min(), axis=1)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %% [markdown]
# ## Filtering data
#
# Now the `df[...]` notation is very flexible:
#   - It accepts column names (strings and lists of strings);
#   - It accepts column numbers (so long as there is no ambiguity with column names);
#   - It accepts _binary data series!_
#
# This means that you can write
#
#         df[ (df['column_name2']==MD) & ( (df['column_name1']==5) | (df['column_name1']==6) ) ]
#
# for what you would write in SQL as
#
# >         SELECT * FROM df WHERE
#             column_name2='MD" AND (column_name1=5 OR column_name1=6)
#
# Boolean operators on a data frame return a data series of bools.

# %%
(df['State_Code'] == 39).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: State_Code, dtype: bool

# %%
((df['State_Code'] == 39) & (df['Census_Tract_Number'] == 9613)).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df[(df['State_Code'] == 39) & (df['Census_Tract_Number'] == 9613)]
# Out:
#        State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 51958        39.0        143.0               9613.0       21        2
# 57340        39.0         31.0               9613.0       21        2
#
#        PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID  LOG_AMT_ALL
# 51958      9.52381     2110      262     12.41710  3.914396e+10     7.654917
# 57340      9.52381     2533      203      8.01421  3.903196e+10     7.837554

# %%
df.sort_values('State_Code')
# Out:
#        State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 23999         1.0         49.0              9613.00       16        4
# 55215         1.0          3.0               102.00        8        1
# 65492         1.0         27.0                  NaN        1        0
# 45193         1.0         95.0               311.00       20        3
# 33750         1.0         39.0              9618.00       14        3
# 23024         1.0         89.0                 5.01        9        3
# 65502         1.0         25.0                  NaN        2        0
# 65507         1.0         99.0               756.00        1        0
# 39229         1.0        103.0                54.04       60       14
# 65472         1.0        113.0                  NaN        2        0
# 30071         1.0         15.0                15.00       27        9
# 45229         1.0        121.0               109.00       16        2
# 55160         1.0         43.0              9657.00       22        3
# 55154         1.0        117.0               302.16      148       17
# 15874         1.0        117.0               303.20       71       31
# 30065         1.0         97.0                37.05       35       11
# 6359          1.0         27.0              9590.00        4        3
# 30059         1.0         87.0              2323.00        2        1
# 3243          1.0        101.0                28.00       42       26
# 8248          1.0        101.0                56.05       23       14
# 65470         1.0         65.0               401.00        5        0
# 23005         1.0        103.0                52.00       38       14
# 65458         1.0         93.0                  NaN        1        0
# 30146         1.0         73.0               127.04       41       14
# 65301         1.0         73.0                 3.00        1        0
# 22881         1.0         13.0              9533.00        6        2
# 1208          1.0         97.0                50.00        2        2
# 65317         1.0         63.0               601.00        9        0
# 3185          1.0         47.0              9563.00       12        8
# 30134         1.0        121.0               101.01       50       19
# ...           ...          ...                  ...      ...      ...
# 28851        72.0        107.0              9548.01        7        2
# 3563         72.0         21.0               311.22       22       17
# 8469         72.0        127.0                83.00        5        3
# 8472         72.0         35.0              2602.02       19       12
# 123          72.0        137.0              1222.02        5        5
# 17203        72.0         61.0               406.02       28       11
# 66595        72.0        127.0                87.00        2        0
# 71397        72.0         31.0               501.07       23        0
# 17230        72.0         61.0               401.01        9        4
# 29032        72.0         21.0               301.03       10        3
# 55524        72.0         73.0              9560.00        7        1
# 17244        72.0         41.0              2402.02        4        2
# 45483        72.0         99.0              4202.00        6        1
# 28961        72.0         75.0              7103.01       55       16
# 45512        72.0          9.0              2505.00       12        2
# 34661        72.0         97.0               820.22        3        1
# 7213         72.0        127.0                79.00       16        9
# 14416        72.0         41.0              2404.02        5        2
# 45532        72.0        113.0               725.00       22        6
# 967          72.0         53.0              1503.02       10       10
# 28902        72.0        119.0              1304.01       16        5
# 28882        72.0        113.0               730.06        3        1
# 11170        72.0        127.0                82.01       15        9
# 5892         72.0         31.0               510.02       30       20
# 34736        72.0         61.0               404.42       11        3
# 11168        72.0        139.0               601.03       10        6
# 14363        72.0         21.0               310.04        6        3
# 11162        72.0         57.0              2703.00       16        9
# 20977        72.0         45.0              9520.00        2        1
# 40651         NaN          NaN                  NaN     9477     1932
#
#        PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID  LOG_AMT_ALL
# 23999      25.0000     2184      799     36.58420  1.049961e+09     7.689371
# 55215      12.5000      774       76      9.81912  1.003010e+09     6.652863
# 65492       0.0000       82        0      0.00000           NaN     4.418841
# 45193      15.0000     1495      263     17.59200  1.095031e+09     7.310550
# 33750      21.4286     1243      333     26.79000  1.039962e+09     7.126087
# 23024      33.3333      615      232     37.72360  1.089001e+09     6.423247
# 65502       0.0000      232        0      0.00000           NaN     5.451038
# 65507       0.0000      116        0      0.00000  1.099076e+09     4.762174
# 39229      23.3333     9263     2051     22.14190  1.103005e+09     9.133891
# 65472       0.0000      435        0      0.00000           NaN     6.077642
# 30071      33.3333     2111      637     30.17530  1.015002e+09     7.655391
# 45229      12.5000     1662      292     17.56920  1.121011e+09     7.416378
# 55160      13.6364     4217      416      9.86483  1.043966e+09     8.347116
# 55154      11.4865    40995     4046      9.86950  1.117030e+09    10.621230
# 15874      43.6620     8024     3807     47.44520  1.117030e+09     8.990317
# 30065      31.4286     5772     1742     30.18020  1.097004e+09     8.660947
# 6359       75.0000      422      282     66.82460  1.027959e+09     6.047372
# 30059      50.0000      424      128     30.18870  1.087232e+09     6.052089
# 3243       61.9048     3513     2735     77.85370  1.101003e+09     8.164510
# 8248       60.8696     2438     1511     61.97700  1.101006e+09     7.799343
# 65470       0.0000      467        0      0.00000  1.065040e+09     6.148468
# 23005      36.8421     4750     1793     37.74740  1.103005e+09     8.466110
# 65458       0.0000       45        0      0.00000           NaN     3.828641
# 30146      34.1463     7435     2237     30.08740  1.073013e+09     8.914088
# 65301       0.0000       23        0      0.00000  1.073000e+09     3.178054
# 22881      33.3333      512      194     37.89060  1.013953e+09     6.240276
# 1208      100.0000      128      128    100.00000  1.097005e+09     4.859812
# 65317       0.0000      927        0      0.00000  1.063060e+09     6.833032
# 3185       66.6667      868      678     78.11060  1.047956e+09     6.767343
# 30134      38.0000     7565     2277     30.09910  1.121010e+09     8.931420
# ...            ...      ...      ...          ...           ...          ...
# 28851      28.5714      691      217     31.40380  7.210795e+10     6.539586
# 3563       77.2727     2705     2068     76.45100  7.202103e+10     7.903227
# 8469       60.0000      522      321     61.49430  7.212701e+10     6.259581
# 8472       63.1579     2825     1737     61.48670  7.203526e+10     7.946618
# 123       100.0000      492      492    100.00000  7.213712e+10     6.200509
# 17203      39.2857     8805     3993     45.34920  7.206104e+10     9.083189
# 66595       0.0000      199        0      0.00000  7.212701e+10     5.298317
# 71397       0.0000     4506        0      0.00000  7.203105e+10     8.413387
# 17230      44.4444     1194      541     45.30990  7.206104e+10     7.085901
# 29032      30.0000     1118      349     31.21650  7.202103e+10     7.020191
# 55524      14.2857      649       62      9.55316  7.207396e+10     6.476972
# 17244      50.0000      616      279     45.29220  7.204124e+10     6.424869
# 45483      16.6667      501       87     17.36530  7.209942e+10     6.218600
# 28961      29.0909     7422     2322     31.28540  7.207571e+10     8.912339
# 45512      16.6667     1251      217     17.34610  7.200925e+10     7.132498
# 34661      33.3333      320       83     25.93750  7.209708e+10     5.771441
# 7213       56.2500     2237     1444     64.55070  7.212701e+10     7.713338
# 14416      40.0000      886      442     49.88710  7.204124e+10     6.787845
# 45532      27.2727     4344      753     17.33430  7.211307e+10     8.376781
# 967       100.0000      958      958    100.00000  7.205315e+10     6.865891
# 28902      31.2500     2603      816     31.34840  7.211913e+10     7.864804
# 28882      33.3333      204       64     31.37250  7.211307e+10     5.323010
# 11170      60.0000     1958     1089     55.61800  7.212701e+10     7.580189
# 5892       66.6667     4540     3093     68.12780  7.203105e+10     8.420903
# 34736      27.2727     2698      698     25.87100  7.206104e+10     7.900637
# 11168      60.0000     1237      688     55.61840  7.213906e+10     7.121252
# 14363      50.0000      642      321     50.00000  7.202103e+10     6.466145
# 11162      56.2500     1555      865     55.62700  7.205727e+10     7.349874
# 20977      50.0000      278      112     40.28780  7.204595e+10     5.631212
# 40651      20.3862  1575871   331515     21.03690           NaN    14.270319
#
# [72035 rows x 11 columns]

# %% [markdown]
# **Note:** selecting rows by binary data series only if they share the same data index!
#
# **Exercise:**
# 1. Plot the histogram of percentages for different states in the same graph to compare them.
# 2. Notice that there is a spike at 100%.  This means that the FHA has insured 100% of the houses in that census tract.  See what happens to the histogram when we restrict it to the case where the total number of loans is non-negligible.

# %%
#RBM: OK, this clearly DIDN'T work:
#mygroup = df.groupby('State_Code')
#mygroup['PCT_NUM_FHA'].hist(bins=40)
df['PCT_NUM_FHA'].hist(bins=40)
df['State_Code'].hist(bins=40,alpha=.4)

# %% [markdown]
# ## Joining data
#
# The analogue of a
#
# >
#     SELECT *
#         FROM df1
#         INNER JOIN df2
#         ON df1.field_name=df2.field_name;
#
# is
#
#     df_joined = df1.merge(df2, on='field_name')
#
# You can also do left / right / outer joins, mix-and-match column names, etc.  For that consult the Pandas documentation. (The example below will do a left join.)
#
# Of course, just looking at the distribution of insurance by census tract isn't interesting unless we know more about the census tract.

# %%
# The first row is the column names, so we don't have to specify those
df_geo = pd.read_csv('small_data/2013_Gaz_tracts_national.tsv', sep='\t')
df_geo.head()
# Out:
#   USPS       GEOID     ALAND  AWATER  ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# 0   AL  1001020100   9809939   36312       3.788        0.014  32.481794
# 1   AL  1001020200   3340498    5846       1.290        0.002  32.475758
# 2   AL  1001020300   5349274    9054       2.065        0.003  32.474024
# 3   AL  1001020400   6382705   16244       2.464        0.006  32.471030
# 4   AL  1001020500  11397734   48412       4.401        0.019  32.458916
#
#    INTPTLONG
# 0                                         -86.490249
# 1                                         -86.472468
# 2                                         -86.459703
# 3                                         -86.444835
# 4                                         -86.421817

# %%
df_joined = df.merge(df_geo, on='GEOID', how='left')
df_joined.head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA        GEOID  LOG_AMT_ALL USPS  \
# 0        100.0      258      258        100.0          NaN     5.556828  NaN
# 1        100.0       71       71        100.0   2.8049e+10     4.276666   MS
# 2        100.0      215      215        100.0          NaN     5.375278  NaN
# 3        100.0      206      206        100.0  3.91131e+10     5.332719   OH
# 4        100.0      303      303        100.0   1.2105e+10     5.717028   FL
#
#          ALAND     AWATER  ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# 0          NaN        NaN         NaN          NaN        NaN
# 1    8162270.0    22648.0       3.151        0.009  32.365904
# 2          NaN        NaN         NaN          NaN        NaN
# 3    5382347.0        0.0       2.078        0.000  39.729932
# 4  105120002.0  1800522.0      40.587        0.695  28.224489
#
#    INTPTLONG
# 0                                                NaN
# 1                                         -90.262379
# 2                                                NaN
# 3                                         -84.268323
# 4                                         -81.739745

# %% [markdown]
# ## Aggregating data
#
# The analog of SQL's `GROUP BY` is
#
#     grouped = df.groupby(['field_name1', ...])...
#
# The above is analogous to
# >
#     SELECT mean(df.value1), std(df.value2)
#         FROM df
#         GROUP BY df.field_name1, ...
#
# Pandas is somewhat more flexible in how you can use grouping, not requiring you to specify an aggregation function up front.  The `.groupby()` method that can later be aggregated.

# %%
usps_groups = df_joined.groupby('USPS')
usps_groups

# %% [markdown]
# The reason Pandas doesn't require you to specify an aggregation function up front is because the groupby method by itself does little work. It returns a `DataFrameGroupBy` datatype that contains a dictionary of group keys to lists of row numbers.

# %%
print type(usps_groups.groups)
usps_groups.groups['AK'][:5]
# Out:
# <type 'dict'>
# Int64Index([91, 298, 536, 2528, 4146], dtype='int64')

# %% [markdown]
# We can retrieve the group of data associated with one key:

# %%
usps_groups.get_group('AK').head()
# Out:
#       State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 91           2.0         50.0                  3.0        1        1
# 298          2.0         20.0                  4.0        1        1
# 536          2.0        122.0                  1.0        1        1
# 2528         2.0        185.0                  1.0       11        8
# 4146         2.0        122.0                 12.0        3        2
#
#       PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA      GEOID  LOG_AMT_ALL USPS  \
# 91       100.0000      121      121     100.0000   2.05e+09     4.804021   AK
# 298      100.0000      192      192     100.0000   2.02e+09     5.262690   AK
# 536      100.0000       39       39     100.0000  2.122e+09     3.688879   AK
# 2528      72.7273     1958     1604      81.9203  2.185e+09     7.580189   AK
# 4146      66.6667      530      392      73.9623  2.122e+09     6.274762   AK
#
#              ALAND        AWATER  ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# 91    4.930719e+10  6.258804e+08   19037.615      241.654  61.468804
# 298   5.336808e+07  2.393787e+07      20.606        9.242  61.266668
# 536   1.982658e+10  1.006239e+10    7655.087     3885.112  60.123779
# 2528  2.532416e+08  3.781985e+08      97.777      146.023  71.287938
# 4146  2.498757e+09  4.721135e+09     964.775     1822.840  59.356474
#
#       INTPTLONG
# 91                                          -156.692206
# 298                                         -149.830858
# 536                                         -152.841141
# 2528                                        -156.685618
# 4146                                        -151.771450

# %% [markdown]
# Observe that this is the same as:

# %%
df_joined.iloc[usps_groups.groups['AK'][:5]]
# Out:
#       State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 91           2.0         50.0                  3.0        1        1
# 298          2.0         20.0                  4.0        1        1
# 536          2.0        122.0                  1.0        1        1
# 2528         2.0        185.0                  1.0       11        8
# 4146         2.0        122.0                 12.0        3        2
#
#       PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA      GEOID  LOG_AMT_ALL USPS  \
# 91       100.0000      121      121     100.0000   2.05e+09     4.804021   AK
# 298      100.0000      192      192     100.0000   2.02e+09     5.262690   AK
# 536      100.0000       39       39     100.0000  2.122e+09     3.688879   AK
# 2528      72.7273     1958     1604      81.9203  2.185e+09     7.580189   AK
# 4146      66.6667      530      392      73.9623  2.122e+09     6.274762   AK
#
#              ALAND        AWATER  ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# 91    4.930719e+10  6.258804e+08   19037.615      241.654  61.468804
# 298   5.336808e+07  2.393787e+07      20.606        9.242  61.266668
# 536   1.982658e+10  1.006239e+10    7655.087     3885.112  60.123779
# 2528  2.532416e+08  3.781985e+08      97.777      146.023  71.287938
# 4146  2.498757e+09  4.721135e+09     964.775     1822.840  59.356474
#
#       INTPTLONG
# 91                                          -156.692206
# 298                                         -149.830858
# 536                                         -152.841141
# 2528                                        -156.685618
# 4146                                        -151.771450

# %%
usps_groups.mean().head()  # Takes the mean of the rows in each group
# Out:
#       State_Code  County_Code  Census_Tract_Number    NUM_ALL    NUM_FHA  \
# USPS
# AK           2.0    98.357616             9.449338  49.079470  12.251656
# AL           1.0    75.836331          1889.544523  32.163669   8.333633
# AR           5.0    78.663690          3196.877113  37.946429   8.427083
# AZ           4.0    14.893676          2446.197818  52.276581  15.538568
# CA           6.0    54.777636          2005.292730  39.154278  11.303073
#
#       PCT_NUM_FHA       AMT_ALL      AMT_FHA  PCT_AMT_FHA  LOG_AMT_ALL  \
# USPS
# AK      27.172880  12450.741722  2905.072848    27.456326     8.791516
# AL      28.754330   5189.795863  1112.598022    29.368947     7.607937
# AR      21.377452   5377.254464  1105.171131    22.321766     7.848935
# AZ      33.198714   9571.252259  2425.145935    34.168339     8.423604
# CA      29.568614  12726.953972  2882.465766    32.965875     8.887090
#
#              ALAND        AWATER   ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# USPS
# AK    4.658549e+09  9.506639e+08  1798.675881   367.053397  61.124912
# AL    1.132807e+08  2.623693e+06    43.737926     1.013006  32.961141
# AR    1.981421e+08  4.362258e+06    76.503085     1.684271  35.078429
# AZ    1.443226e+08  6.508373e+05    55.723284     0.251290  33.315336
# CA    4.902491e+07  8.379937e+05    18.928632     0.323551  35.504532
#
#       INTPTLONG
# USPS
# AK                                          -148.239871
# AL                                           -86.761186
# AR                                           -92.548487
# AZ                                          -111.890482
# CA                                          -119.414014

# %%
# This is the analog of
# SELECT USPS, SUM(AMT_FHA), SUM(AMT_ALL), ... FROM df GROUP BY USPS;
df_by_state = usps_groups['AMT_FHA', 'AMT_ALL', 'NUM_FHA', 'NUM_ALL'].sum()
df_by_state.head()
# Out:
#        AMT_FHA   AMT_ALL  NUM_FHA  NUM_ALL
# USPS
# AK      438666   1880062     1850     7411
# AL     1237209   5771053     9267    35766
# AR      742675   3613515     5663    25500
# AZ     3489785  13773032    22360    75226
# CA    22607179  99817500    88650   307087

# %%
df_by_state['PCT_AMT_FHA'] = 100.0 * df_by_state['AMT_FHA']  / df_by_state['AMT_ALL']

# This sure looks different than the census-tract level histogram!
df_by_state['PCT_AMT_FHA'].hist(bins=20)

# %% [markdown]
# You can also specify a specific aggregation function per column:

# %%
usps_groups['NUM_FHA', 'NUM_ALL'].agg({'NUM_FHA': np.sum,
                                       'NUM_ALL': np.mean}).head()
# Out:
#         NUM_ALL  NUM_FHA
# USPS
# AK    49.079470     1850
# AL    32.163669     9267
# AR    37.946429     5663
# AZ    52.276581    22360
# CA    39.154278    88650

# %% [markdown]
# The groupby function is especially useful when you define your own aggregation functions. Here, we define a function that returns the row for the census track located farthest to the north. The apply function attempts to 'combine results together in an intelligent way.' The list of Series objects from each call to `farthest_north` for each USPS code is collapsed into a single DataFrame table.

# %%
def farthest_north(state_df):
    # descending sort, then select row 0
    # the datatype will be a pandas Series
    return state_df.sort_values('INTPTLAT', ascending=False).iloc[0]

df_joined.groupby('USPS').apply(farthest_north)[:10]
# Out:
#       State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# USPS
# AK           2.0        185.0                 1.00       11        8
# AL           1.0         71.0              9502.00       10        2
# AR           5.0          7.0               208.03       91        9
# AZ           4.0          5.0                21.00       38       10
# CA           6.0         93.0                 4.00        2        0
# CO           8.0         75.0              9659.00        5        0
# CT           9.0          3.0              5243.00       46       16
# DC          11.0          1.0                16.00       41       10
# DE          10.0          3.0               112.02       23        9
# FL          12.0         33.0                40.00        4        0
#
#       PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID  LOG_AMT_ALL  \
# USPS
# AK       72.72730     1958     1604     81.92030  2.185000e+09     7.580189
# AL       20.00000      700      216     30.85710  1.071950e+09     6.552508
# AR        9.89011     9673      909      9.39729  5.007021e+09     9.177197
# AZ       26.31580     7078     1831     25.86890  4.005002e+09     8.864888
# CA        0.00000      741        0      0.00000  6.093000e+09     6.609349
# CO        0.00000      388        0      0.00000  8.075966e+09     5.963579
# CT       34.78260     6441     2580     40.05590  9.003524e+09     8.770594
# DC       24.39020    23623     6368     26.95680  1.100100e+10    10.070018
# DE       39.13040     5656     2370     41.90240  1.000301e+10     8.640649
# FL        0.00000      192        0      0.00000  1.203300e+10     5.262690
#
#      USPS         ALAND       AWATER  ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# USPS
# AK     AK  2.532416e+08  378198536.0      97.777      146.023  71.287938
# AL     AL  9.275512e+07    2986584.0      35.813        1.153  34.965286
# AR     AR  1.397141e+07     295088.0       5.394        0.114  36.486278
# AZ     AZ  5.956008e+07    4650137.0      22.996        1.795  36.916588
# CA     CA  5.329775e+08    3118247.0     205.784        1.204  41.946648
# CO     CO  1.425537e+09    3036714.0     550.403        1.172  40.924098
# CT     CT  1.314194e+07     242922.0       5.074        0.094  42.024605
# DC     DC  2.650934e+06      35617.0       1.024        0.014  38.984972
# DE     DE  3.704573e+06          0.0       1.430        0.000  39.832216
# FL     FL  9.382286e+07    4475275.0      36.225        1.728  30.967491
#
#       INTPTLONG
# USPS
# AK                                          -156.685618
# AL                                           -85.777448
# AR                                           -94.283383
# AZ                                          -111.470183
# CA                                          -122.634808
# CO                                          -103.073557
# CT                                           -72.530403
# DC                                           -77.038232
# DE                                           -75.521217
# FL                                           -87.277931

# %% [markdown]
# ## Sorting by indices and columns
#
# We can sort by the row (or column) index.

# %%
df_by_state.sort_index(ascending=False).head()
# Out:
#       AMT_FHA   AMT_ALL  NUM_FHA  NUM_ALL  PCT_AMT_FHA
# USPS
# WY     248573   1313697     1418     6644    18.921639
# WV     282703   1675079     2129    11739    16.876995
# WI     971178   7500688     7104    47913    12.947852
# WA    3201463  17267705    15019    68902    18.540177
# VT      77355    940893      421     4777     8.221445

# %% [markdown]
# We can also sort by the value in a column:

# %%
df_by_state.sort_values('AMT_FHA').head()
# Out:
#       AMT_FHA  AMT_ALL  NUM_FHA  NUM_ALL  PCT_AMT_FHA
# USPS
# VT      77355   940893      421     4777     8.221445
# HI     208685  3564599      571     9008     5.854375
# SD     224819  1316044     1642     8474    17.082939
# WY     248573  1313697     1418     6644    18.921639
# MT     254623  1600554     1548     8522    15.908429

# %% [markdown]
# ### Pandas HTML data import example
#
# Pandas takes a "batteries included" approach and throws in a whole lot of convenience functions.  For instance it has import functions for a variety of formats.  One of the pleasant surprises is a command `read_html` that's meant to automate the process of extracting tabular data from HTML.  In particular, it works pretty well with tables on Wikipedia.
#
# Let's do an example: We'll try to extract the list of the world's tallest structures from
# http://en.wikipedia.org/wiki/List_of_tallest_buildings_and_structures_in_the_world.

# %%
dfs = pd.read_html('http://en.wikipedia.org/wiki/List_of_tallest_buildings_and_structures_in_the_world', header=0, parse_dates=False)

# There are several tables on the page.  By inspection we can figure out which one we want
tallest = dfs[2]

# The coordinates column needs to be fixed up.  This is a bit of string parsing:
def clean_lat_long(s):
    try:
        parts = s.split("/")
    except AttributeError:
        return (None, None)
    if len(parts) < 3:
        return (None, None)
    m = re.search(r"(\d+[.]\d+);[^\d]*(\d+[.]\d+)[^\d]", parts[2])
    if not m:
        return (None, None)
    return (m.group(1), m.group(2))

tallest['Clean_Coordinates'] = tallest['Coordinates'].apply(clean_lat_long)
tallest['Latitude'] = tallest['Clean_Coordinates'].apply(lambda x:x[0])
tallest['Longitude'] = tallest['Clean_Coordinates'].apply(lambda x:x[1])

# Et voila
tallest.head()
# Out:
#                    Category               Structure               Country  \
# 0                 Mixed use            Burj Khalifa  United Arab Emirates
# 1     Self-supporting tower           Tokyo Skytree                 Japan
# 2  Guyed steel lattice mast            KVLY-TV mast         United States
# 3            Clock building    Abraj Al Bait Towers          Saudi Arabia
# 4                    Office  One World Trade Center         United States
#
#                       City Height (metres)  Height (feet) Year built  \
# 0                    Dubai           828.1         2717.0       2010
# 1                    Tokyo             634         2080.0       2011
# 2  Blanchard, North Dakota           628.8         2063.0       1963
# 3                    Mecca             601         1972.0       2011
# 4             New York, NY             541         1776.0       2013
#
#                                          Coordinates       Clean_Coordinates  \
# 0  25°11′50.0″N 55°16′26.6″E﻿ / ﻿25.197222°N 55.2...  (25.197222, 55.274056)
# 1  35°42′36.5″N 139°48′39″E﻿ / ﻿35.710139°N 139.8...  (35.710139, 139.81083)
# 2  47°20′32″N 97°17′25″W﻿ / ﻿47.34222°N 97.29028°...    (47.34222, 97.29028)
# 3  21°25′08″N 39°49′35″E﻿ / ﻿21.41889°N 39.82639°...    (21.41889, 39.82639)
# 4  40°42′46.8″N 74°0′48.6″W﻿ / ﻿40.713000°N 74.01...  (40.713000, 74.013500)
#
#     Latitude  Longitude
# 0  25.197222  55.274056
# 1  35.710139  139.81083
# 2   47.34222   97.29028
# 3   21.41889   39.82639
# 4  40.713000  74.013500

# %% [markdown]
# **Exercise**
#
# 1. Parse the table rankings of [UK universities available on Wikipedia](https://en.wikipedia.org/wiki/Rankings_of_universities_in_the_United_Kingdom)

# %% [markdown]
# ## Pandas Timestamps
#
# Pandas comes with excellent tools for managing temporal data. Central to this is the Timestamp class, which can infer timestamps from many sensible inputs:

# %%
print pd.Timestamp('July 4, 2016')
print pd.Timestamp('Monday, July 4, 2016')
print pd.Timestamp('Tuesday, July 4th, 2016')  # notice it ignored 'Tuesday'
print pd.Timestamp('Monday, July 4th, 2016 05:00 PM')
print pd.Timestamp('07/04/2016T17:20:13.123456')
print pd.Timestamp(1467651600000000000)  # number of ns since the epoch, 1/1/1970
# Out:
# 2016-07-04 00:00:00
# 2016-07-04 00:00:00
# 2016-07-04 00:00:00
# 2016-07-04 17:00:00
# 2016-07-04 17:20:13.123456
# 2016-07-04 17:00:00

# %% [markdown]
# It can manage timestamps with timezones:

# %%
july4 = pd.Timestamp('Monday, July 4th, 2016 05:00 PM').tz_localize('US/Eastern')
labor_day = pd.Timestamp('9/5/2016 12:00', tz='US/Eastern')
thanksgiving = pd.Timestamp('11/24/2016 16:00')  # no timezone

# %% [markdown]
# Pandas can do calculations on Timestamps if they are both localized to the same timezone or neither has a timezone.

# %%
print labor_day - july4
# print thanksgiving - july4  # generates an error
# Out:
# 62 days 19:00:00

# %% [markdown]
# The time series offsets are useful for calculating dates relative to another date. Observe it skips over weekend days but is oblivious to holidays. Pandas does support [Custom Calendars](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#holidays-holiday-calendars) if you need them.

# %%
from pandas.tseries.offsets import BDay, Day, BMonthEnd

print july4 + Day(5)  # 5 calendar days later, a Saturday.
print july4 + BDay(5)  # 5 business days later, or the following Monday.
print july4 - BDay(1)  # 1 business day earlier, or the previous Friday.
print july4 + BMonthEnd(1)  # last business day of the month.
# Out:
# 2016-07-09 17:00:00-04:00
# 2016-07-11 17:00:00-04:00
# 2016-07-01 17:00:00-04:00
# 2016-07-29 17:00:00-04:00

# %% [markdown]
# Pandas can generate a range of dates. Here, we generate a list of business days in January of 2016:

# %%
business_days = pd.date_range('1/1/2016', '1/31/2016', freq='B')
business_days
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-04', '2016-01-05', '2016-01-06',
#                '2016-01-07', '2016-01-08', '2016-01-11', '2016-01-12',
#                '2016-01-13', '2016-01-14', '2016-01-15', '2016-01-18',
#                '2016-01-19', '2016-01-20', '2016-01-21', '2016-01-22',
#                '2016-01-25', '2016-01-26', '2016-01-27', '2016-01-28',
#                '2016-01-29'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# This can in turn be used in as a DataFrame index:

# %%
time_df = DataFrame(np.random.rand(len(business_days)),
                    index=business_days,
                   columns=['random'])
time_df.head()
# Out:
#               random
# 2016-01-01  0.286081
# 2016-01-04  0.523323
# 2016-01-05  0.931584
# 2016-01-06  0.937694
# 2016-01-07  0.620870

# %% [markdown]
# The same timezone functions are still available.

# %%
time_df.tz_localize('UTC').tz_convert('US/Pacific').head()
# Out:
#                              random
# 2015-12-31 16:00:00-08:00  0.286081
# 2016-01-03 16:00:00-08:00  0.523323
# 2016-01-04 16:00:00-08:00  0.931584
# 2016-01-05 16:00:00-08:00  0.937694
# 2016-01-06 16:00:00-08:00  0.620870

# %% [markdown]
# ## DataFrame Resampling
#
# Pandas DataFrames provide a resampling method for changing the frequency of your data. Perhaps you have daily data but only care about the last data-point in each month. You can resample to downgrade the the data to a different frequency.

# %%
year2016 = pd.date_range(start='1/1/2016', end='12/31/2016')

daily_data_df = DataFrame(np.random.rand(len(year2016)), index=year2016, columns=['random'])
daily_data_df.head()
# Out:
#               random
# 2016-01-01  0.211681
# 2016-01-02  0.660748
# 2016-01-03  0.426120
# 2016-01-04  0.581328
# 2016-01-05  0.656830

# %% [markdown]
# This makes a new DataFrame with each data-point coming from the last day of the month.

# %%
monthly_data = daily_data_df.resample('1M').last()
monthly_data
# Out:
#               random
# 2016-01-31  0.916336
# 2016-02-29  0.764455
# 2016-03-31  0.425528
# 2016-04-30  0.952738
# 2016-05-31  0.330881
# 2016-06-30  0.514779
# 2016-07-31  0.466936
# 2016-08-31  0.225056
# 2016-09-30  0.518971
# 2016-10-31  0.531496
# 2016-11-30  0.108411
# 2016-12-31  0.046402

# %% [markdown]
# What about resampling in the other direction? This is possible, but you may have gaps in the result. To avoid this, use the `ffill` and `bfill` methods, like so.

# %%
daily_data2 = monthly_data.resample('1D').bfill()
daily_data2.head()
# Out:
#               random
# 2016-01-31  0.916336
# 2016-02-01  0.764455
# 2016-02-02  0.764455
# 2016-02-03  0.764455
# 2016-02-04  0.764455

# %% [markdown]
# You'll also notice that the first date in that DataFrame is 2016-01-31, not 2016-01-01 like in the original list. We can fix that if we want to. The `loc[year2016]` code fixes the index and the `bfill()` fills in the January values.

# %%
daily_data3 = daily_data2.loc[year2016].bfill()
daily_data3.head()
# Out:
#               random
# 2016-01-01  0.916336
# 2016-01-02  0.916336
# 2016-01-03  0.916336
# 2016-01-04  0.916336
# 2016-01-05  0.916336

# %% [markdown]
# ## A little bit more on `read_csv`
#
# We've already used the Pandas `read_csv` method a few times in this notebook, but let's take a closer look at what it can do. It is a powerful tool for inputting a wide variety of delimited text files and overcoming many typical data input problems. Because CSV files are so popular, over time many features were added and now it can handle pretty much any CSV file you are likely to find.
#
# You can access the `read_csv` documentation to read about all of the parameters, but here are the most useful ones.
#
# * sep: Change the file delimiter. By default it is a comma, but you will find files that use tabs ('\t') and pipes. ('|')
# * header: Row number to use for column header. Some csv files have no header; in this case, pass None instead and use the names parameter.
# * names: List of column names to use, overriding what `read_csv` might name the columns from reading the file.
# * index_col: Make an index out of a column. Without this, it will create a default index of integers.
# * parse_dates: parse certain columns as dates.
# * infer_datetime_format: if the data in a column of dates all have the same format, this will speed up reading the file.

# %% [markdown]
# ## DataFrames and Iterators
#
# Often you will need to loop through data in a DataFrame. Rather than use a `for` loop, you can convert a DataFrame into an iterator of your choosing.
#
# The `iterrows` method creates an iterator that returns tuples of the index value and its row of data as a Pandas Series.

# %%
list(daily_data_df.iterrows())[0]
# Out:
# (Timestamp('2016-01-01 00:00:00', freq='D'), random    0.211681
#  Name: 2016-01-01 00:00:00, dtype: float64)

# %% [markdown]
# The `iteritems` method is similar except it iterates over columns, not rows.

# %%
list(daily_data_df.iteritems())[0]
# Out:
# ('random', 2016-01-01    0.211681
#  2016-01-02    0.660748
#  2016-01-03    0.426120
#  2016-01-04    0.581328
#  2016-01-05    0.656830
#  2016-01-06    0.503626
#  2016-01-07    0.463408
#  2016-01-08    0.594023
#  2016-01-09    0.210198
#  2016-01-10    0.925032
#  2016-01-11    0.510753
#  2016-01-12    0.305977
#  2016-01-13    0.445006
#  2016-01-14    0.422335
#  2016-01-15    0.557909
#  2016-01-16    0.449850
#  2016-01-17    0.252286
#  2016-01-18    0.059106
#  2016-01-19    0.402637
#  2016-01-20    0.922987
#  2016-01-21    0.942646
#  2016-01-22    0.904395
#  2016-01-23    0.562824
#  2016-01-24    0.250532
#  2016-01-25    0.977907
#  2016-01-26    0.856510
#  2016-01-27    0.098957
#  2016-01-28    0.959091
#  2016-01-29    0.730360
#  2016-01-30    0.363825
#                  ...
#  2016-12-02    0.109196
#  2016-12-03    0.030582
#  2016-12-04    0.502588
#  2016-12-05    0.862612
#  2016-12-06    0.463288
#  2016-12-07    0.844985
#  2016-12-08    0.615636
#  2016-12-09    0.737329
#  2016-12-10    0.234565
#  2016-12-11    0.240779
#  2016-12-12    0.338162
#  2016-12-13    0.890498
#  2016-12-14    0.607568
#  2016-12-15    0.671142
#  2016-12-16    0.531538
#  2016-12-17    0.079109
#  2016-12-18    0.336582
#  2016-12-19    0.357364
#  2016-12-20    0.423885
#  2016-12-21    0.127322
#  2016-12-22    0.137273
#  2016-12-23    0.573301
#  2016-12-24    0.868758
#  2016-12-25    0.638119
#  2016-12-26    0.437510
#  2016-12-27    0.333299
#  2016-12-28    0.460011
#  2016-12-29    0.770896
#  2016-12-30    0.238556
#  2016-12-31    0.046402
#  Freq: D, Name: random, Length: 366, dtype: float64)

# %% [markdown]
# Finally, `itertuples`. This method returns each row as a tuple. Including the index value in that tuple is optional.

# %%
list(daily_data_df.itertuples(index=True, name=None))[0]
# Out:
# (Timestamp('2016-01-01 00:00:00', freq='D'), 0.21168115839291635)

# %% [markdown]
# ### Exercises
#
# 1. Find a CSV file somewhere on the Internet that contains data that interests you. Open the file with the Pandas `read_csv` function and plot the data.
# 1. Aggregate the data in a meaningful way and plot the results.
# 1. Create a Pandas Timestamp for the day you were born and for today's date. How many days old are you? Seconds? Milliseconds?

# %% [markdown]
# ### Exit Tickets
#
# 1. What is a Pandas DataFrame?
# 1. What is a DataFrame index? How does it differ from a regular DataFrame column?
# 1. What is DataFrame aggregation?

# %% [markdown]
# *Copyright &copy; 2015 The Data Incubator.  All rights reserved.*
