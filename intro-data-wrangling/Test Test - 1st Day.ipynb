# %%
good_food = ['Quinoa Salad with Fresh Veggies', 'Taboule', 'Veggie Burger Sandwich', 'Sprout Sandwich','Homemade Yoshon Whole-Wheat Pasta with Scratch Marainara']
#print good_food
for item in good_food:
    print 'Yummie ' + item + '!!!!\n'
# Out:
# Yummie Quinoa Salad with Fresh Veggies!!!!
#
# Yummie Taboule!!!!
#
# Yummie Veggie Burger Sandwich!!!!
#
# Yummie Sprout Sandwich!!!!
#
# Yummie Homemade Yoshon Whole-Wheat Pasta with Scratch Marainara!!!!

# %%
p4 = {x:x**4 for x in range(1,1001)}
print p4,
# Out:
# {1: 1, 2: 16, 3: 81, 4: 256, 5: 625, 6: 1296, 7: 2401, 8: 4096, 9: 6561, 10: 10000, 11: 14641, 12: 20736, 13: 28561, 14: 38416, 15: 50625, 16: 65536, 17: 83521, 18: 104976, 19: 130321, 20: 160000, 21: 194481, 22: 234256, 23: 279841, 24: 331776, 25: 390625, 26: 456976, 27: 531441, 28: 614656, 29: 707281, 30: 810000, 31: 923521, 32: 1048576, 33: 1185921, 34: 1336336, 35: 1500625, 36: 1679616, 37: 1874161, 38: 2085136, 39: 2313441, 40: 2560000, 41: 2825761, 42: 3111696, 43: 3418801, 44: 3748096, 45: 4100625, 46: 4477456, 47: 4879681, 48: 5308416, 49: 5764801, 50: 6250000, 51: 6765201, 52: 7311616, 53: 7890481, 54: 8503056, 55: 9150625, 56: 9834496, 57: 10556001, 58: 11316496, 59: 12117361, 60: 12960000, 61: 13845841, 62: 14776336, 63: 15752961, 64: 16777216, 65: 17850625, 66: 18974736, 67: 20151121, 68: 21381376, 69: 22667121, 70: 24010000, 71: 25411681, 72: 26873856, 73: 28398241, 74: 29986576, 75: 31640625, 76: 33362176, 77: 35153041, 78: 37015056, 79: 38950081, 80: 40960000, 81: 4304
# ...

# %%
# %%timeit
p4.pprint(tup)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-33-11f5c5777800> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'timeit', u'', u'p4.pprint(tup)')
#
# /opt/conda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-58> in timeit(self, line, cell)
#
# /opt/conda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /opt/conda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#    1047             number = 1
# ...

# %%
class ShoppingCart(object):
    """Creates shopping cart objects
    for users of our fine website."""
    items_in_cart = {}
    def __init__(self, customer_name):
        self.customer_name = customer_name

    def add_item(self, product, price):
        """Add product to the cart."""
        if not product in self.items_in_cart:
            self.items_in_cart[product] = price
            print product + " added."
        else:
            print product + " is already in the cart."

    def remove_item(self, product):
        """Remove product from the cart."""
        if product in self.items_in_cart:
            del self.items_in_cart[product]
            print product + " removed."
        else:
            print product + " is not in the cart."
my_cart = ShoppingCart("Reuven")
my_cart.add_item("Banana",.99)
print "Cart: " + str(my_cart.items_in_cart)
my_cart.add_item("Banana",.99)
my_cart.remove_item("Banana")
print my_cart.items_in_cart
print type(ShoppingCart)
# Out:
# Banana added.
# Cart: {'Banana': 0.99}
# Banana is already in the cart.
# Banana removed.
# {}
# <type 'type'>
