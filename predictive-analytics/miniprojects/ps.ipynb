# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 144

# %%
from grader import score

# %%
import gzip
import ujson as json
import pprint

import pandas as pd
import numpy as np

# %% [markdown]
# # PS Miniproject
#
# ## Introduction
#
# The objective of this miniproject is to apply probability and statistics to yelp data for businesses primarily in AZ and NV. We will study the data to find meaningful patterns in the ratings and data for these businesses.
# `
# ## Metric
#
# Your answers will be assessed based based on how well you apply these standard statistical techniques.
#
# ## Download and parse the incoming data
#
# The data are [here](s3://dataincubator-course/mldata/yelp_train_academic_dataset_business.json.gz).
# Notice that each row of the file is a json blurb.  You can read it with Python.

# %%
# !mkdir -p data/
# !aws s3 cp s3://dataincubator-course/mldata/yelp_train_academic_dataset_business.json.gz data

# %%
# !zcat data/yelp_train_academic_dataset_business.json.gz | head -5
# Out:
# {"business_id": "vcNAWiLM4dR7D2nwwJ7nCA", "full_address": "4840 E Indian School Rd\nSte 101\nPhoenix, AZ 85018", "hours": {"Tuesday": {"close": "17:00", "open": "08:00"}, "Friday": {"close": "17:00", "open": "08:00"}, "Monday": {"close": "17:00", "open": "08:00"}, "Wednesday": {"close": "17:00", "open": "08:00"}, "Thursday": {"close": "17:00", "open": "08:00"}}, "open": true, "categories": ["Doctors", "Health & Medical"], "city": "Phoenix", "review_count": 7, "name": "Eric Goldberg, MD", "neighborhoods": [], "longitude": -111.98375799999999, "state": "AZ", "stars": 3.5, "latitude": 33.499313000000001, "attributes": {"By Appointment Only": true}, "type": "business"}
# {"business_id": "JwUE5GmEO-sH1FuwJgKBlQ", "full_address": "6162 US Highway 51\nDe Forest, WI 53532", "hours": {}, "open": true, "categories": ["Restaurants"], "city": "De Forest", "review_count": 26, "name": "Pine Cone Restaurant", "neighborhoods": [], "longitude": -89.335843999999994, "state": "WI", "stars": 4.0, "latitude": 43.238892999999997, "attributes": {"Take-out": true, "Good For": {"dessert": false, "latenight": false, "lunch": true, "dinner": false, "breakfast": false, "brunch": false}, "Caters": false, "Noise Level": "average", "Takes Reservations": false, "Delivery": false, "Ambience": {"romantic": false, "intimate": false, "touristy": false, "hipster": false, "divey": false, "classy": false, "trendy": false, "upscale": false, "casual": false}, "Parking": {"garage": false, "street": false, "validated": false, "lot": true, "valet": false}, "Has TV": true, "Outdoor Seating": false, "Attire": "casual", "Alcohol": "none", "Waiter Service": true, "Accepts Credit Cards": true, "Good for Kids": true, "Good For Groups": true, "Price Range": 1}, "type": "business"}
# {"business_id": "uGykseHzyS5xAMWoN6YUqA", "full_address": "505 W North St\nDe Forest, WI 53532", "hours": {"Monday": {"close": "22:00", "open": "06:00"}, "Tuesday": {"close": "22:00", "open": "06:00"}, "Friday": {"close": "22:00", "open": "06:00"}, "Wednesday": {"close": "22:00", "open": "06:00"}, "Thursday": {"close": "22:00", "open": "06:00"}, "Sunday": {"close": "21:00", "open": "06:00"}, "Saturday": {"close": "22:00", "open": "06:00"}}, "open": true, "categories": ["American (Traditional)", "Restaurants"], "city": "De Forest", "review_count": 16, "name": "Deforest Family Restaurant", "neighborhoods": [], "longitude": -89.353437, "state": "WI", "stars": 4.0, "latitude": 43.252267000000003, "attributes": {"Take-out": true, "Good For": {"dessert": false, "latenight": false, "lunch": false, "dinner": false, "breakfast": false, "brunch": true}, "Caters": false, "Noise Level": "quiet", "Takes Reservations": false, "Delivery": false, "Parking": {"garage": false, "street": false, "validated": false, "lot": true, "valet": false}, "Has TV": true, "Outdoor Seating": false, "Attire": "casual", "Ambience": {"romantic": false, "intimate": false, "touristy": false, "hipster": false, "divey": false, "classy": false, "trendy": false, "upscale": false, "casual": true}, "Waiter Service": true, "Accepts Credit Cards": true, "Good for Kids": true, "Good For Groups": true, "Price Range": 1}, "type": "business"}
# {"business_id": "LRKJF43s9-3jG9Lgx4zODg", "full_address": "4910 County Rd V\nDe Forest, WI 53532", "hours": {"Monday": {"close": "22:00", "open": "10:30"}, "Tuesday": {"close": "22:00", "open": "10:30"}, "Friday": {"close": "22:00", "open": "10:30"}, "Wednesday": {"close": "22:00", "open": "10:30"}, "Thursday": {"close": "22:00", "open": "10:30"}, "Sunday": {"close": "22:00", "open": "10:30"}, "Saturday": {"close": "22:00", "open": "10:30"}}, "open": true, "categories": ["Food", "Ice Cream & Frozen Yogurt", "Fast Food", "Restaurants"], "city": "De Forest", "review_count": 7, "name": "Culver's", "neighborhoods": [], "longitude": -89.374983, "state": "WI", "stars": 4.5, "latitude": 43.251044999999998, "attributes": {"Take-out": true, "Wi-Fi": "free", "Takes Reservations": false, "Delivery": false, "Parking": {"garage": false, "street": false, "validated": false, "lot": true, "valet": false}, "Wheelchair Accessible": true, "Attire": "casual", "Accepts Credit Cards": true, "Good For Groups": true, "Price Range": 1}, "type": "business"}
# {"business_id": "RgDg-k9S5YD_BaxMckifkg", "full_address": "631 S Main St\nDe Forest, WI 53532", "hours": {"Monday": {"close": "22:00", "open": "11:00"}, "Tuesday": {"close": "22:00", "open": "11:00"}, "Friday": {"close": "22:30", "open": "11:00"}, "Wednesday": {"close": "22:00", "open": "11:00"}, "Thursday": {"close": "22:00", "open": "11:00"}, "Sunday": {"close": "21:00", "open": "16:00"}, "Saturday": {"close": "22:30", "open": "11:00"}}, "open": true, "categories": ["Chinese", "Restaurants"], "city": "De Forest", "review_count": 3, "name": "Chang Jiang Chinese Kitchen", "neighborhoods": [], "longitude": -89.343721700000003, "state": "WI", "stars": 4.0, "latitude": 43.2408748, "attributes": {"Take-out": true, "Has TV": false, "Outdoor Seating": false, "Attire": "casual"}, "type": "business"}
#
# gzip: stdout: Broken pipe

# %%
with gzip.open("data/yelp_train_academic_dataset_business.json.gz") as fin:
    data = [json.loads(line) for line in fin]
df = pd.DataFrame(data)

# %%
data[:2]
# Out:
# [{u'attributes': {u'By Appointment Only': True},
#   u'business_id': u'vcNAWiLM4dR7D2nwwJ7nCA',
#   u'categories': [u'Doctors', u'Health & Medical'],
#   u'city': u'Phoenix',
#   u'full_address': u'4840 E Indian School Rd\nSte 101\nPhoenix, AZ 85018',
#   u'hours': {u'Friday': {u'close': u'17:00', u'open': u'08:00'},
#    u'Monday': {u'close': u'17:00', u'open': u'08:00'},
#    u'Thursday': {u'close': u'17:00', u'open': u'08:00'},
#    u'Tuesday': {u'close': u'17:00', u'open': u'08:00'},
#    u'Wednesday': {u'close': u'17:00', u'open': u'08:00'}},
#   u'latitude': 33.499313,
#   u'longitude': -111.983758,
#   u'name': u'Eric Goldberg, MD',
#   u'neighborhoods': [],
#   u'open': True,
#   u'review_count': 7,
#   u'stars': 3.5,
#   u'state': u'AZ',
#   u'type': u'business'},
#  {u'attributes': {u'Accepts Credit Cards': True,
#    u'Alcohol': u'none',
#    u'Ambience': {u'casual': False,
#     u'classy': False,
#     u'divey': False,
#     u'hipster': False,
#     u'intimate': False,
#     u'romantic': False,
#     u'touristy': False,
#     u'trendy': False,
#     u'upscale': False},
#    u'Attire': u'casual',
#    u'Caters': False,
#    u'Delivery': False,
#    u'Good For': {u'breakfast': False,
#     u'brunch': False,
#     u'dessert': False,
#     u'dinner': False,
#     u'latenight': False,
#     u'lunch': True},
#    u'Good For Groups': True,
#    u'Good for Kids': True,
#    u'Has TV': True,
#    u'Noise Level': u'average',
#    u'Outdoor Seating': False,
#    u'Parking': {u'garage': False,
#     u'lot': True,
#     u'street': False,
#     u'valet': False,
#     u'validated': False},
#    u'Price Range': 1,
#    u'Take-out': True,
#    u'Takes Reservations': False,
#    u'Waiter Service': True},
#   u'business_id': u'JwUE5GmEO-sH1FuwJgKBlQ',
#   u'categories': [u'Restaurants'],
#   u'city': u'De Forest',
#   u'full_address': u'6162 US Highway 51\nDe Forest, WI 53532',
#   u'hours': {},
#   u'latitude': 43.238893,
#   u'longitude': -89.335844,
#   u'name': u'Pine Cone Restaurant',
#   u'neighborhoods': [],
#   u'open': True,
#   u'review_count': 26,
#   u'stars': 4.0,
#   u'state': u'WI',
#   u'type': u'business'}]

# %%
df.head(2)
# Out:
#                                           attributes             business_id  \
# 0                     {u'By Appointment Only': True}  vcNAWiLM4dR7D2nwwJ7nCA
# 1  {u'Take-out': True, u'Price Range': 1, u'Outdo...  JwUE5GmEO-sH1FuwJgKBlQ
#
#                     categories       city  \
# 0  [Doctors, Health & Medical]    Phoenix
# 1                [Restaurants]  De Forest
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
#
#                                                hours   latitude   longitude  \
# 0  {u'Thursday': {u'close': u'17:00', u'open': u'...  33.499313 -111.983758
# 1                                                 {}  43.238893  -89.335844
#
#                    name neighborhoods  open  review_count  stars state  \
# 0     Eric Goldberg, MD            []  True             7    3.5    AZ
# 1  Pine Cone Restaurant            []  True            26    4.0    WI
#
#        type
# 0  business
# 1  business

# %% [markdown]
# ## city_z_score
# Do certain cities have better amenities than others?  We can test this by comparing the average score or rating of businesses in one city vs. the average across all businesses in the dataset.  We will also want to use statistics to help determine if this difference is statistically significant.
#
# Compute the z score for average ratings for every city.
#
# **Note**:
# 1. Only look at cities with at least five businesses, both for the city averages and when computing the average across all cities.
# 2. Estimate the population's standard deviation and mean.
# 3. Estimate each city's mean and use the population statistics to compute the z score.
# 4. Do not do any cleaning of the city names.  (You will get Las Vegas twice.  That's okay.)

# %%
city_counts = df.groupby('city').size().sort_values()

# %%
popular_cities = city_counts[city_counts >= 5].index   #Cool filter.  Functions like a where clause.  Will be applied to popular cities.

# %%
df_popular_cities = df[df['city'].isin(city_counts[city_counts >= 5].index)]

# %%
states = df_popular_cities.groupby('state')
states

# %%
average = df_popular_cities['stars'].mean()

# %%
stdev = df_popular_cities['stars'].std(ddof=1)

# %%
mean_by_city = df_popular_cities.groupby('city')['stars'].mean()

# %%
count_by_city = df_popular_cities.groupby('city').size()

# %%
# ~1:45 in #9: 
# the normalization '(stdev / np.sqrt(count_ty_city_))' is trying to ensure that outliers are normalized out.
# As the count_by_city gets larger, its square root also gets larger.
# Dividing the Standard Deviation by the square root of the count 
# As the count gets larger, any differences between the mean by city and average will result in a larger z-score.
# If you had a city with a million business and the mean was .1 higher than the average, because there is so much data there,
# you may be able to conclude that, although the difference is small, it is statistically significantly.  
# If you had a city with only 5 businesses with the same difference between the mean and the population average, 
# you would likely conclude that the difference is not as significant.  
# This is how count by city works itself into this equation... to equalize the differences between city sizes.

#####  This is what standard error hopes to accomplish #####

solution = (mean_by_city - average) / (stdev / np.sqrt(count_by_city))

# %%
# We're done the calculations, but the data type is a series.
# We need it to be a set of tuples to do the scoring piece. 
#list(solution.to_frame().itertuples())
#list(solution.iteritems()) # I like this solution best.  Seems simplest.
#zip(solution.index, solution)

# %%
# Convert the series into a set of tuples... 
# We learned about itertuples() at the end of the pandas lecture.
# TODO: Review Pandas Lecture !!!!!

city_z_score_tuples = list(solution.to_frame().itertuples())
#city_z_score_tuples

# %%
# This defaults to a partial answer.  If you execute this, you will get a low score.  
def city_z_score():
    # return [('Ahwatukee', 0.047382042549430063)] * 70
    return city_z_score_tuples
score('ps__city_z_score', city_z_score)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# **Question:**
# 1. For computing the standard deviation, you should really be assuming a single degree of freedom.  Why is this not that important in this case?
# > don't know
# 2. Which cities have the most statistically high ratings?  Do you notice a pattern?
# > Does this mean that Las Vegas has low ratings in general?

# %% [markdown]
# ## Data Sets Notation Review (RBM)
#
# **Note**:
#
#     > Square Brackets ([]) are used for python lists
#     > Curly Brackets ({}) with no colons are for sets
#     > Curly Brackets ({}) with colons are for dictionaries
#     > Parentheses (()) are used for tuples

# %% [markdown]
# ## good_for_kids_ci
# Which cities are the most child friendly?  Let's estimate the 2-sigma confidence interval for fraction of venues which are 'Good for Kids' in each city.
#
# **Note**:
# 1. Ignore any businesses that don't have the 'Good for Kids' attribute specified. **IMPORTANT**: These are the businesses for which you have no information and they should be filtered out. All businesses that have the 'Good for Kids' attribute, whether that be True or False, should be included.
# 2. Only look at cities with at least five businesses (satisfying the above condition).
# 3. In this simplified schema, a venue is either 'Good for Kids' or not.  What variable are we using to model the underlying distribution?
# 4. Notice that some of have a unrealistic confidence intervals.  Can you apply the "Rule of Three" to generate more realistic confidence intervals in this case?

# %%
d1 = {"Good for Kids": True, "Formal": False}
d2 = {"Good for Kids": False, "Formal": True}
d3 = {"Allows Pets": True}

def get_GfK(x):
    if x.has_key('Good for Kids'):
        return x["Good for Kids"]
    return None
    
print get_GfK(d1)
print get_GfK(d2)
print get_GfK(d3)
# Out:
# True
# False
# None

# %%
#df['has_gfk'] = df['attributes'].apply(lambda x: x.has_key("Good for Kids"))
df['gfk'] = df['attributes'].apply(get_GfK)
df_hasgfk = df[df['gfk'].notnull()]

# %%
city_hasgfk_gt5 = df_hasgfk.groupby('city')['gfk'].count()

# %%
city_hasgfk_gt5  >= 5
# Out:
# city
# Ahwatukee               False
# Anthem                   True
# Apache Junction          True
# Arcadia                 False
# Atlanta                 False
# Avondale                 True
# Boulder City             True
# Buckeye                  True
# Cambridge               False
# Carefree                 True
# Casa Grande              True
# Cave Creek               True
# Central City Village    False
# Chandler                 True
# City of Edinburgh       False
# Clark County            False
# Coolidge                 True
# Cottage Grove            True
# Cramond                 False
# Dalkeith                False
# Dane                    False
# De Forest               False
# DeForest                False
# Edinburgh                True
# El Mirage                True
# Enterprise              False
# Fitchburg                True
# Florence                 True
# Fort McDowell           False
# Fort Mcdowell           False
#                         ...
# San Tan Valley           True
# Scottsdale               True
# Sedona                  False
# South Queensferry       False
# Spring Valley           False
# St Clements             False
# St Jacobs               False
# Stockbridge             False
# Stoughton               False
# Summerlin               False
# Summerlin South         False
# Sun City                 True
# Sun City West            True
# Sun Lakes               False
# Sun Prairie              True
# Surprise                 True
# Tempe                    True
# Tolleson                 True
# Tonopah                 False
# Tortilla Flat           False
# Trempealeau             False
# Verona                   True
# Waddell                 False
# Water of Leith          False
# Waterloo                 True
# Waunakee                 True
# Whitney                 False
# Wickenburg               True
# Windsor                 False
# Youngtown                True
# Name: gfk, Length: 115, dtype: bool

# %%
# popular_cities = city_counts[city_counts >= 5].index
gfk_cities = df_hasgfk[df_hasgfk >= 5]
gfk_cities
# Out:
#                                               attributes  \
# 1      {u'Take-out': True, u'Price Range': 1, u'Outdo...
# 2      {u'Take-out': True, u'Outdoor Seating': False,...
# 9      {u'Alcohol': u'full_bar', u'Noise Level': u'lo...
# 11                              {u'Good for Kids': True}
# 12     {u'Take-out': True, u'Price Range': 1, u'Outdo...
# 13     {u'Take-out': True, u'Accepts Credit Cards': T...
# 14     {u'Take-out': True, u'Caters': True, u'Attire'...
# 15     {u'Take-out': True, u'Price Range': 2, u'Outdo...
# 16     {u'Take-out': True, u'Accepts Credit Cards': T...
# 17                              {u'Good for Kids': True}
# 20     {u'By Appointment Only': False, u'Good for Kid...
# 26     {u'Take-out': True, u'Accepts Credit Cards': F...
# 27     {u'Price Range': 1, u'Good For': {u'dessert': ...
# 28     {u'Take-out': True, u'Price Range': 2, u'Outdo...
# 29     {u'Take-out': True, u'Price Range': 1, u'Parki...
# 31     {u'Take-out': True, u'Outdoor Seating': False,...
# 33     {u'Take-out': True, u'Accepts Credit Cards': T...
# 35     {u'Take-out': True, u'Accepts Credit Cards': T...
# 38     {u'Price Range': 1, u'Outdoor Seating': True, ...
# 39     {u'Take-out': False, u'Accepts Credit Cards': ...
# 40     {u'Take-out': False, u'Accepts Credit Cards': ...
# 41                              {u'Good for Kids': True}
# 45     {u'Take-out': True, u'Accepts Credit Cards': F...
# 48     {u'Accepts Credit Cards': True, u'Price Range'...
# 50     {u'Alcohol': u'full_bar', u'Attire': u'casual'...
# 53     {u'Take-out': True, u'Drive-Thru': True, u'Out...
# 56     {u'Alcohol': u'full_bar', u'Noise Level': u'av...
# 59     {u'Take-out': True, u'Price Range': 2, u'Outdo...
# 61     {u'Take-out': True, u'Accepts Credit Cards': T...
# 62     {u'By Appointment Only': True, u'Accepts Credi...
# ...                                                  ...
# 37881  {u'Take-out': True, u'Takes Reservations': Tru...
# 37883  {u'Take-out': True, u'Drive-Thru': False, u'Ou...
# 37884  {u'Take-out': True, u'Accepts Credit Cards': T...
# 37885  {u'Take-out': True, u'Price Range': 2, u'Outdo...
# 37889  {u'Take-out': True, u'Accepts Credit Cards': T...
# 37891                           {u'Good for Kids': True}
# 37892                          {u'Good for Kids': False}
# 37894                           {u'Good for Kids': True}
# 37896  {u'Alcohol': u'full_bar', u'Caters': True, u'N...
# 37898  {u'Take-out': True, u'Accepts Credit Cards': T...
# 37901  {u'Alcohol': u'full_bar', u'Noise Level': u'av...
# 37902  {u'Take-out': True, u'Accepts Credit Cards': T...
# 37904  {u'Take-out': True, u'Price Range': 1, u'Outdo...
# 37906  {u'Take-out': True, u'Accepts Credit Cards': T...
# 37907                           {u'Good for Kids': True}
# 37909  {u'Take-out': False, u'Price Range': 4, u'Outd...
# 37911  {u'Take-out': True, u'Good For': {u'dessert': ...
# 37914  {u'Take-out': True, u'Price Range': 1, u'Outdo...
# 37915  {u'Take-out': True, u'Accepts Credit Cards': T...
# 37917  {u'Take-out': True, u'Accepts Credit Cards': T...
# 37923  {u'Take-out': True, u'Price Range': 2, u'Outdo...
# 37924  {u'Take-out': True, u'Accepts Credit Cards': T...
# 37926  {u'Take-out': True, u'Outdoor Seating': False,...
# 37927                           {u'Good for Kids': True}
# 37929  {u'Take-out': True, u'Accepts Credit Cards': T...
# 37930  {u'Take-out': True, u'Price Range': 2, u'Outdo...
# 37931  {u'Take-out': True, u'Accepts Credit Cards': T...
# 37932  {u'Alcohol': u'full_bar', u'Noise Level': u'qu...
# 37935                          {u'Good for Kids': False}
# 37936  {u'Take-out': True, u'Accepts Credit Cards': T...
#
#                   business_id  \
# 1      JwUE5GmEO-sH1FuwJgKBlQ
# 2      uGykseHzyS5xAMWoN6YUqA
# 9      _wZTYYL7cutanzAnJUTGMA
# 11     1tkeiIa-daD8LbM6mHm_9A
# 12     zOc8lbjViUZajbY7M0aUCQ
# 13     UgjVZTSOaYoEvws_lAP_Dw
# 14     HxPpZSY6Q1eARuiahhra6A
# 15     SKLw05kEIlZcpTD5pqma8Q
# 16     77ESrCo7hQ96VpCWWdvoxg
# 17     368m5-RtrrYWf4hPM_bMlg
# 20     x7xS2DJvu8klyNzcpN8QHg
# 26     ShEYKerTwb2LSORE5o_s7A
# 27     HaBkx5PwvbBpQ2iNCgHnVQ
# 28     KW6HejC-67KSL9J8Cz1dSw
# 29     wl-7A4jC0f27MOEmW-XTbQ
# 31     suQyHycqv8nA7EualcUB3g
# 33     AYoLKzRFajucKnjIFxc__A
# 35     uga5g16PncJOtY7Sc3A05w
# 38     xbJ9tdGbcVJIUkNgHSCwZQ
# 39     koRLvzIl-4fCybOIdk56jA
# 40     ckLRf3lYn9DxmNxd-mu2yA
# 41     Bznf9AaGgdsLI01H_ifrUA
# 45     X47o6R2rWiqGqvBtC7VS3Q
# 48     lN-5-YTsaJr_IByyA476iw
# 50     IEmqrFe96NOhU07TA0rZdw
# 53     KFJ1jBfFkRfyn3AoAUl3YQ
# 56     G1qUGBNYNS220jKlPAlFsA
# 59     6oDZ78JiSKjXVLcurCpnhw
# 61     kiAsweI4sOjDzGyz3Y_HsQ
# 62     mbtGl2I2A2To-8jiggN99g
# ...                       ...
# 37881  wd3nrdoEpikmGcf4NX0ziA
# 37883  WVEBPBymHcpYXPsXryPoNQ
# 37884  ScSwwoFcIC0mf1vU-6p8eQ
# 37885  q1QRFM3Rh8K9jPMWNus6hA
# 37889  nuHftEWNyMIsa4R4OpqlQg
# 37891  B0M3_Y-vtglFswwPUQecLg
# 37892  Xbswoo00rr2qaiiMFjUMqg
# 37894  uLHU3U-mLOdtIPTWldQQ2Q
# 37896  M3G_xbxxfkupkemCZzXh9g
# 37898  cb4YeNdl6MUWis906tzFVQ
# 37901  vZ4CIMfeos6K7OyYDIlwrQ
# 37902  WgsKcV4zZ2JnxUj9lKdn9Q
# 37904  LsKF7GFQ0j5U1jLMwq0_hQ
# 37906  Ah5sMocfo1FTk6vekMLM6g
# 37907  suO9O-o1wk9DxYIemojpXQ
# 37909  aybLDQRhUwOr7WoQfdofPQ
# 37911  fmfiSDAJtjxbnRBBtYhnNw
# 37914  51vtDjP79vBjaI5dbkPoPw
# 37915  F8ZrWvngdHYnKrALwZAdBw
# 37917  0EXVIF07vw-QTTy9V7-ebg
# 37923  8K4pWvuJmGWXDgCugYKYvw
# 37924  wmm19sGdCiL5IZhViYQY2Q
# 37926  5se9c1ggSm2oMrnWO3ZSgw
# 37927  UH4BReVAqpMVjyVroEJAGA
# 37929  KN-3Sg8TZ-y67026TFwmjw
# 37930  ZpB2O-WAbbRHdP0V8GrwXA
# 37931  OEUIE8VBa1BbBfr5EPcTOA
# 37932  yZXEELxi8KMwzXCHP345GQ
# 37935  nYer89hXYAoddMEKTxw7kA
# 37936  BMjggIgOghBMEXPo8q7q3w
#
#                                               categories         city  \
# 1                                          [Restaurants]    De Forest
# 2                  [American (Traditional), Restaurants]    De Forest
# 9      [Bars, American (Traditional), Nightlife, Loun...   Mc Farland
# 11                                [Active Life, Bowling]   Mc Farland
# 12                                  [Pizza, Restaurants]   Mc Farland
# 13                                [Chinese, Restaurants]   Mc Farland
# 14     [Event Planning & Services, Party & Event Plan...    Middleton
# 15     [Party & Event Planning, Asian Fusion, Event P...    Middleton
# 16                                [Mexican, Restaurants]    Middleton
# 17     [Active Life, Arts & Entertainment, Stadiums &...    Middleton
# 20     [Pilates, Yoga, Weight Loss Centers, Health & ...    Middleton
# 26     [Bakeries, Food, Breakfast & Brunch, Coffee & ...    Middleton
# 27        [Bars, American (New), Nightlife, Restaurants]    Middleton
# 28                                [Chinese, Restaurants]    Middleton
# 29                                [Chinese, Restaurants]    Middleton
# 31                                 [Diners, Restaurants]    Middleton
# 33                     [Food, Ice Cream & Frozen Yogurt]    Middleton
# 35                     [Burgers, Fast Food, Restaurants]    Middleton
# 38                        [Bars, Nightlife, Restaurants]    Middleton
# 39                           [Cajun/Creole, Restaurants]    Middleton
# 40     [Hotels & Travel, Event Planning & Services, H...    Middleton
# 41                   [Active Life, Amateur Sports Teams]    Middleton
# 45                     [Breakfast & Brunch, Restaurants]    Middleton
# 48                   [Active Life, Bowling, Restaurants]    Middleton
# 50                 [American (Traditional), Restaurants]    Middleton
# 53                     [Burgers, Fast Food, Restaurants]    Middleton
# 56     [Bars, American (Traditional), Nightlife, Rest...    Middleton
# 59                 [American (Traditional), Restaurants]    Middleton
# 61     [Food, Ice Cream & Frozen Yogurt, Restaurants,...    Middleton
# 62               [Skin Care, Hair Salons, Beauty & Spas]    Middleton
# ...                                                  ...          ...
# 37881                               [Pizza, Restaurants]    Las Vegas
# 37883                             [Burgers, Restaurants]    Henderson
# 37884  [Food, Desserts, Coffee & Tea, Cafes, Restaura...    Las Vegas
# 37885                      [American (New), Restaurants]        Tempe
# 37889                                [Thai, Restaurants]    Las Vegas
# 37891                        [Yelp Events, Local Flavor]      Phoenix
# 37892  [Active Life, Gyms, Fitness & Instruction, Yog...   Scottsdale
# 37894  [Active Life, Martial Arts, Yoga, Kids Activit...    Las Vegas
# 37896                    [Seafood, Restaurants, Italian]    Las Vegas
# 37898                            [Japanese, Restaurants]    Las Vegas
# 37901  [Mexican, Bars, Cocktail Bars, Nightlife, Rest...    Las Vegas
# 37902  [Burgers, Fast Food, Sandwiches, Salad, Restau...    Las Vegas
# 37904  [Bars, Restaurants, Wine Bars, Nightlife, Amer...      Phoenix
# 37906                              [German, Restaurants]    Henderson
# 37907                        [Yelp Events, Local Flavor]   Scottsdale
# 37909                         [Steakhouses, Restaurants]      Madison
# 37911        [American (New), Comfort Food, Restaurants]  Sun Prairie
# 37914                               [Pizza, Restaurants]      Phoenix
# 37915  [Food, Tea Rooms, Coffee & Tea, Asian Fusion, ...     Waterloo
# 37917                               [Cafes, Restaurants]  Queen Creek
# 37923                          [Sushi Bars, Restaurants]   Scottsdale
# 37924                          [Vietnamese, Restaurants]    Las Vegas
# 37926                            [Filipino, Restaurants]    Las Vegas
# 37927                     [Active Life, Amusement Parks]    Henderson
# 37929                       [Chicken Wings, Restaurants]    Las Vegas
# 37930                      [American (New), Restaurants]    Henderson
# 37931  [Food, Juice Bars & Smoothies, American (New),...    Henderson
# 37932  [Bars, Turkish, Mediterranean, Nightlife, Loun...    Las Vegas
# 37935                        [Yelp Events, Local Flavor]      Phoenix
# 37936              [Kosher, Italian, Pizza, Restaurants]      Phoenix
#
#                                             full_address  \
# 1                6162 US Highway 51\nDe Forest, WI 53532
# 2                    505 W North St\nDe Forest, WI 53532
# 9             4506 Larson Beach Rd\nMc Farland, WI 53558
# 11                 4711 Farwell St\nMc Farland, WI 53558
# 12                    5813 Main St\nMc Farland, WI 53558
# 13            4850 Larson Beach Rd\nMc Farland, WI 53558
# 14              6401 University Ave\nMiddleton, WI 53562
# 15                  2039 Allen Blvd\nMiddleton, WI 53562
# 16              6230 University Ave\nMiddleton, WI 53562
# 17                8312 Forsythia St\nMiddleton, WI 53562
# 20                  2529 Allen Blvd\nMiddleton, WI 53562
# 26      6720 Frank Lloyd Wright Ave\nMiddleton, WI 53562
# 27                2401 Parmenter St\nMiddleton, WI 53562
# 28                 8414 Old Sauk Rd\nMiddleton, WI 53562
# 29                  2608 Allen Blvd\nMiddleton, WI 53562
# 31               8302 Greenway Blvd\nMiddleton, WI 53562
# 33                  1650 Deming Way\nMiddleton, WI 53562
# 35               8308 Greenway Blvd\nMiddleton, WI 53562
# 38                   1914 Aurora St\nMiddleton, WI 53562
# 39                 7464 Hubbard Ave\nMiddleton, WI 53562
# 40           1313 John Q Hammons Dr\nMiddleton, WI 53562
# 41                     7625 Lisa Ln\nMiddleton, WI 53562
# 45                2227 Parmenter St\nMiddleton, WI 53562
# 48              6815 University Ave\nMiddleton, WI 53562
# 50                 6625 Century Ave\nMiddleton, WI 53562
# 53              3311 W Beltline Hwy\nMiddleton, WI 53562
# 56                 7508 Hubbard Ave\nMiddleton, WI 53562
# 59                 1021 N Gammon Rd\nMiddleton, WI 53562
# 61                2906 Parmenter St\nMiddleton, WI 53562
# 62     6661 University Ave\nSte 103\nMiddleton, WI 53562
# ...                                                  ...
# 37881  5625 S Rainbow Blvd\nSte E\nSpring Valley\nLas...
# 37883              1321 W Sunset Rd\nHenderson, NV 89014
# 37884  7729 S Rainbow Blvd\nSte 9B\nSouthwest\nLas Ve...
# 37885               603 W University Dr\nTempe, AZ 85281
# 37889  1910 Village Center Cir\nSte 3\nSummerlin\nLas...
# 37891  Pointe Hilton Squaw Peak\n7677 N 16th St\nPhoe...
# 37892  7135 E. Camelback Rd\nSte 235\nScottsdale, AZ ...
# 37894  2223 S Rainbow Blvd\nWestside\nLas Vegas, NV 8...
# 37896      7770 W Ann Rd\nNorthwest\nLas Vegas, NV 89149
# 37898  3650 S Decatur Blvd\nChinatown\nLas Vegas, NV ...
# 37901  11011 W Charleston Blvd\nSouth Summerlin\nLas ...
# 37902  5010 S Fort Apache Rd\nSpring Valley\nLas Vega...
# 37904                 14 W Vernon Ave\nPhoenix, AZ 85003
# 37906       10890 S Eastern\nAnthem\nHenderson, NV 89052
# 37907  Hopdoddy Burger Bar\n11055 N Scottsdale Rd\nSc...
# 37909        14 W Mifflin St\nCapitol\nMadison, WI 53703
# 37911  2804 Prairie Lakes Dr\nSte 106\nSun Prairie, W...
# 37914               1031 NW Grand Ave\nPhoenix, AZ 85007
# 37915                255 King Street N\nWaterloo, ON N2J
# 37917  22721 S Ellsworth Rd\nSte 107\nQueen Creek, AZ...
# 37923             4320 N Miller Rd\nScottsdale, AZ 85251
# 37924  4860 W Desert Inn Rd\nSte 9\nWestside\nLas Veg...
# 37926     6820 W Flamingo Rd\nSte A\nLas Vegas, NV 89103
# 37927               900 Galleria Dr\nHenderson, NV 89011
# 37929  6475 W Charleston Blvd\nSte 150\nWestside\nLas...
# 37930  140 S Green Valley Pkwy\nSte 142\nHenderson, N...
# 37931        19 S Stephanie\nSte140\nHenderson, NV 89012
# 37932  2550 S Rainbow Blvd\nSte  W1\nWestside\nLas Ve...
# 37935           FilmBar\n815 N 2nd St\nPhoenix, AZ 85004
# 37936                   6505 N 7th St\nPhoenix, AZ 85014
#
#                                                    hours   latitude  \
# 1                                                     {}  43.238893
# 2      {u'Monday': {u'close': u'22:00', u'open': u'06...  43.252267
# 9                                                     {}  43.017701
# 11     {u'Monday': {u'close': u'02:00', u'open': u'11...  43.013156
# 12     {u'Tuesday': {u'close': u'22:00', u'open': u'1...  43.014164
# 13                                                    {}  43.017939
# 14                                                    {}  43.093265
# 15     {u'Monday': {u'close': u'14:00', u'open': u'11...  43.090642
# 16     {u'Monday': {u'close': u'21:00', u'open': u'06...  43.091061
# 17     {u'Monday': {u'close': u'21:00', u'open': u'09...  43.110157
# 20     {u'Monday': {u'close': u'00:00', u'open': u'00...  43.103072
# 26     {u'Monday': {u'close': u'15:00', u'open': u'07...  43.107227
# 27     {u'Monday': {u'close': u'11:00', u'open': u'07...  43.101460
# 28     {u'Monday': {u'close': u'21:00', u'open': u'11...  43.075345
# 29     {u'Monday': {u'close': u'22:00', u'open': u'11...  43.103663
# 31                                                    {}  43.090563
# 33                                                    {}  43.095486
# 35     {u'Monday': {u'close': u'23:00', u'open': u'05...  43.090653
# 38                                                    {}  43.095696
# 39     {u'Monday': {u'close': u'23:00', u'open': u'17...  43.095553
# 40     {u'Monday': {u'close': u'17:00', u'open': u'09...  43.087887
# 41                                                    {}  43.108380
# 45     {u'Monday': {u'close': u'14:00', u'open': u'06...  43.099933
# 48                                                    {}  43.096947
# 50                                                    {}  43.104535
# 53                                                    {}  43.097688
# 56     {u'Monday': {u'close': u'22:30', u'open': u'10...  43.095724
# 59     {u'Monday': {u'close': u'23:00', u'open': u'11...  43.084460
# 61     {u'Monday': {u'close': u'22:00', u'open': u'10...  43.106274
# 62     {u'Tuesday': {u'close': u'20:00', u'open': u'1...  43.096650
# ...                                                  ...        ...
# 37881  {u'Monday': {u'close': u'22:00', u'open': u'11...  36.086549
# 37883  {u'Monday': {u'close': u'22:00', u'open': u'11...  36.063166
# 37884  {u'Monday': {u'close': u'01:00', u'open': u'11...  36.048129
# 37885  {u'Monday': {u'close': u'23:00', u'open': u'11...  33.421531
# 37889  {u'Monday': {u'close': u'20:30', u'open': u'11...  36.193105
# 37891                                                 {}  33.547811
# 37892  {u'Monday': {u'close': u'19:00', u'open': u'05...  33.501772
# 37894  {u'Monday': {u'close': u'21:00', u'open': u'15...  36.147218
# 37896  {u'Sunday': {u'close': u'22:00', u'open': u'17...  36.263691
# 37898  {u'Monday': {u'close': u'16:00', u'open': u'11...  36.123621
# 37901  {u'Monday': {u'close': u'00:00', u'open': u'11...  36.157109
# 37902  {u'Monday': {u'close': u'00:00', u'open': u'11...  36.097833
# 37904                                                 {}  33.474235
# 37906  {u'Tuesday': {u'close': u'21:00', u'open': u'1...  35.995282
# 37907                                                 {}  33.586425
# 37909                                                 {}  43.075200
# 37911                                                 {}  43.166396
# 37914  {u'Tuesday': {u'close': u'04:00', u'open': u'2...  33.454960
# 37915                                                 {}  43.477274
# 37917  {u'Monday': {u'close': u'16:00', u'open': u'07...  33.241852
# 37923  {u'Monday': {u'close': u'21:30', u'open': u'17...  33.499192
# 37924  {u'Monday': {u'close': u'22:00', u'open': u'11...  36.129992
# 37926  {u'Monday': {u'close': u'22:00', u'open': u'10...  36.114987
# 37927                                                 {}  36.070909
# 37929  {u'Monday': {u'close': u'20:00', u'open': u'11...  36.158604
# 37930                                                 {}  36.022463
# 37931  {u'Monday': {u'close': u'20:00', u'open': u'08...  36.028049
# 37932  {u'Monday': {u'close': u'22:00', u'open': u'11...  36.143397
# 37935                                                 {}  33.457106
# 37936  {u'Monday': {u'close': u'21:00', u'open': u'11...  33.531310
#
#        longitude                                     name  \
# 1            NaN                     Pine Cone Restaurant
# 2            NaN               Deforest Family Restaurant
# 9            NaN          Beach House Restaurant & Lounge
# 11           NaN                             Spartan Bowl
# 12           NaN                            Spartan Pizza
# 13           NaN             Main Moon Chinese Restaurant
# 14           NaN            Crandalls Carryout & Catering
# 15           NaN       Imperial Garden Chinese Restaurant
# 16           NaN                                Mi Cocina
# 17           NaN                       Keva Sports Center
# 20           NaN                     Harbor Athletic Club
# 26           NaN                    Prairie Cafe & Bakery
# 27           NaN                  Paul's Neighborhood Bar
# 28           NaN                        Chin's Asia Fresh
# 29           NaN                   Grand China Restaurant
# 31           NaN                                   Dennys
# 33           NaN                      Cold Stone Creamery
# 35           NaN                               McDonald's
# 38           NaN                         Hody Bar & Grill
# 39           NaN                         Louisianne's Etc
# 40           NaN                    Marriott-Madison West
# 41           NaN                 Bowling Green Rec Center
# 45           NaN               Three Sisters Old Town Inn
# 48           NaN                     Middleton Sport Bowl
# 50           NaN           Stamm House At Pheasant Branch
# 53           NaN                                 Hardee's
# 56           NaN            The Village Green Bar & Grill
# 59           NaN            Nitty Gritty Restaurant & Bar
# 61           NaN                                 Culver's
# 62           NaN                                  Tangles
# ...          ...                                      ...
# 37881        NaN                    Grinders Pizza Lounge
# 37883        NaN              Five Guys Burgers and Fries
# 37884        NaN                         Ice Monster Cafe
# 37885        NaN                              The Revival
# 37889        NaN                  Brown Rice Thai Kitchen
# 37891        NaN  Yelp's Pool Party For A Hydrating Cause
# 37892        NaN                             Fit Republic
# 37894        NaN                   Quest ATA Martial Arts
# 37896        NaN               North Beach Italian Bistro
# 37898        NaN                 Japanese Cuisine By Omae
# 37901        NaN                                Mercadito
# 37902        NaN                               Applebee's
# 37904        NaN                            Oven and Vine
# 37906        NaN                          Bavarian Castle
# 37907        NaN   Elite Event: Burger Battle at Hopdoddy
# 37909        NaN                          Rare Steakhouse
# 37911        NaN                                     MACS
# 37914        NaN               Grand Avenue Pizza Company
# 37915        NaN                                  Chatime
# 37917        NaN                   The Bistro Queen Creek
# 37923        NaN                                  Sushi J
# 37924        NaN                                  Pho Lan
# 37926        NaN                           D' Pinoy Joint
# 37927        NaN                 Cowabunga Bay-Water Park
# 37929        NaN                            702 Wing Spot
# 37930        NaN                             LYFE Kitchen
# 37931        NaN                              Presto Cafe
# 37932        NaN        Maza Mediterranean Grill & Lounge
# 37935        NaN    Yelp's Secret Cinema: Made In Arizona
# 37936        NaN          LaBella Pizzeria and Restaurant
#
#                  neighborhoods  open  review_count  stars state      type  \
# 1                           []   NaN          26.0    NaN    WI  business
# 2                           []   NaN          16.0    NaN    WI  business
# 9                           []   NaN          31.0    NaN    WI  business
# 11                          []   NaN           NaN    NaN    WI  business
# 12                          []   NaN           NaN    NaN    WI  business
# 13                          []   NaN           8.0    NaN    WI  business
# 14                          []   NaN           5.0    NaN    WI  business
# 15                          []   NaN          41.0    NaN    WI  business
# 16                          []   NaN          17.0    NaN    WI  business
# 17                          []   NaN           NaN    NaN    WI  business
# 20                          []   NaN           5.0    5.0    WI  business
# 26                          []   NaN          38.0    NaN    WI  business
# 27                          []   NaN          11.0    NaN    WI  business
# 28                          []   NaN          28.0    NaN    WI  business
# 29                          []   NaN           6.0    NaN    WI  business
# 31                          []   NaN           5.0    NaN    WI  business
# 33                          []   NaN           6.0    NaN    WI  business
# 35                          []   NaN           6.0    NaN    WI  business
# 38                          []   NaN          10.0    NaN    WI  business
# 39                          []   NaN          56.0    NaN    WI  business
# 40                          []   NaN          35.0    NaN    WI  business
# 41                          []   NaN           NaN    NaN    WI  business
# 45                          []   NaN          19.0    NaN    WI  business
# 48                          []   NaN          10.0    NaN    WI  business
# 50                          []   NaN           7.0    NaN    WI  business
# 53                          []   NaN           5.0    NaN    WI  business
# 56                          []   NaN          34.0    NaN    WI  business
# 59                          []   NaN          16.0    NaN    WI  business
# 61                          []   NaN          12.0    NaN    WI  business
# 62                          []   NaN           7.0    NaN    WI  business
# ...                        ...   ...           ...    ...   ...       ...
# 37881          [Spring Valley]   NaN           7.0    5.0    NV  business
# 37883                       []   NaN           6.0    NaN    NV  business
# 37884              [Southwest]   NaN          32.0    NaN    NV  business
# 37885                       []   NaN          15.0    NaN    AZ  business
# 37889              [Summerlin]   NaN           8.0    NaN    NV  business
# 37891                       []   NaN          29.0    5.0    AZ  business
# 37892                       []   NaN           8.0    NaN    AZ  business
# 37894               [Westside]   NaN           9.0    5.0    NV  business
# 37896  [Northwest, Centennial]   NaN           5.0    5.0    NV  business
# 37898              [Chinatown]   NaN          15.0    NaN    NV  business
# 37901        [South Summerlin]   NaN          85.0    NaN    NV  business
# 37902          [Spring Valley]   NaN          33.0    NaN    NV  business
# 37904                       []   NaN          11.0    5.0    AZ  business
# 37906                 [Anthem]   NaN           6.0    NaN    NV  business
# 37907                       []   NaN          25.0    5.0    AZ  business
# 37909                [Capitol]   NaN           7.0    NaN    WI  business
# 37911                       []   NaN           7.0    NaN    WI  business
# 37914                       []   NaN           6.0    NaN    AZ  business
# 37915                       []   NaN           6.0    NaN    ON  business
# 37917                       []   NaN           5.0    5.0    AZ  business
# 37923                       []   NaN          15.0    NaN    AZ  business
# 37924               [Westside]   NaN          12.0    NaN    NV  business
# 37926                       []   NaN           9.0    NaN    NV  business
# 37927                       []   NaN          26.0    NaN    NV  business
# 37929               [Westside]   NaN           9.0    NaN    NV  business
# 37930                       []   NaN          34.0    NaN    NV  business
# 37931                       []   NaN          27.0    NaN    NV  business
# 37932               [Westside]   NaN          18.0    NaN    NV  business
# 37935                       []   NaN          17.0    5.0    AZ  business
# 37936                       []   NaN           5.0    5.0    AZ  business
#
#        has_gfk  gfk
# 1          NaN  NaN
# 2          NaN  NaN
# 9          NaN  NaN
# 11         NaN  NaN
# 12         NaN  NaN
# 13         NaN  NaN
# 14         NaN  NaN
# 15         NaN  NaN
# 16         NaN  NaN
# 17         NaN  NaN
# 20         NaN  NaN
# 26         NaN  NaN
# 27         NaN  NaN
# 28         NaN  NaN
# 29         NaN  NaN
# 31         NaN  NaN
# 33         NaN  NaN
# 35         NaN  NaN
# 38         NaN  NaN
# 39         NaN  NaN
# 40         NaN  NaN
# 41         NaN  NaN
# 45         NaN  NaN
# 48         NaN  NaN
# 50         NaN  NaN
# 53         NaN  NaN
# 56         NaN  NaN
# 59         NaN  NaN
# 61         NaN  NaN
# 62         NaN  NaN
# ...        ...  ...
# 37881      NaN  NaN
# 37883      NaN  NaN
# 37884      NaN  NaN
# 37885      NaN  NaN
# 37889      NaN  NaN
# 37891      NaN  NaN
# 37892      NaN  NaN
# 37894      NaN  NaN
# 37896      NaN  NaN
# 37898      NaN  NaN
# 37901      NaN  NaN
# 37902      NaN  NaN
# 37904      NaN  NaN
# 37906      NaN  NaN
# 37907      NaN  NaN
# 37909      NaN  NaN
# 37911      NaN  NaN
# 37914      NaN  NaN
# 37915      NaN  NaN
# 37917      NaN  NaN
# 37923      NaN  NaN
# 37924      NaN  NaN
# 37926      NaN  NaN
# 37927      NaN  NaN
# 37929      NaN  NaN
# 37930      NaN  NaN
# 37931      NaN  NaN
# 37932      NaN  NaN
# 37935      NaN  NaN
# 37936      NaN  NaN
#
# [15124 rows x 17 columns]

# %%
# Cities that have 5 business with GFK set (either T or F)

# %%
good_for_kids_ci_tuples = ...

# %%
    return [('Anthem', (0.85714285714285721, 1.0))] * 51

score('ps__good_for_kids_ci', good_for_kids_ci)

# %% [markdown]
# **Question**: For which cities do you need to apply the Rule of Three?  Is there a data feature that's common amongst them?

# %% [markdown]
# ## category_star_ci
# Some categories may be more popular than others.  Compute the 3-sigma confidence interval for the average number of reviews for businesses in each category.
#
# **Note**:
# 1. Category is actually a list of categories that apply to the business.  Let's just set a business's category to be the first one in this list.  Ignore ones that do not have categories defined.
# 2. Only consider categories that have at least 40 businesses.
# 3. What is a good distribution to assume for the number of reviews?  Use the standard deviation from this distribution rather than the sample deviation in computing the confidence interval.

# %%
category_reviews_ci_tuples = ...

# %%
def category_reviews_ci():
    return [('Active Life', (16.788552393175845, 17.431729675326505))] * 119

score('ps__category_reviews_ci', category_reviews_ci)

# %% [markdown]
# **Questions**:
# 1. What categories of businesses tend to have fewer reviews?
# 2. What categories of businesses tend to have more reviews?

# %% [markdown]
# ## review_count_z_score
# Are more popular venues more likely to be highly rated?  Given the large variation in reporting amongst categories, we know that popularity depends on the category.
#
# Separate the venues into those that have (strictly) more reviews than the median for their category, and those that have the same number or fewer.  For each category, compute the average number of stars for both those businesses with more than and less than or equal to the median number of reviews.  Report the z score of the difference of those means.
#
# **Note**:
# 1. Again, category of a business will be defined as the first category and you should ignore businesses that do not have categories.
# 2. Likewise, only consider categories with at least 40 businesses.

# %%
review_count_z_score_tuples = ...

# %%
def review_count_z_score():
    return [('Active Life', -4.8885384947587749)] * 119

score('ps__review_count_z_score', review_count_z_score)

# %% [markdown]
# **Questions**:
# 1. What categories benefit from having more reviewers?
# 2. What categories are hurt by having more reviewers?
# 3. Why did we choose to separate each category by the median number of reviews rather than the mean number of reviews?

# %% [markdown]
# ## For Fun (not graded)!
# What types of categories have the most disagreement?  Use the variance as a proxy.  How would you compute the 2-sigma confidence interval?

# %% [markdown]
# *Copyright &copy; 2017 The Data Incubator.  All rights reserved.*
